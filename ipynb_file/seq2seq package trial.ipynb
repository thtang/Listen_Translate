# %%
import numpy as np
# import seq2seq
# from seq2seq.models import SimpleSeq2Seq
import keras.backend as K
import gensim
from keras.models import Model
from keras.layers import Input, LSTM, Dense, GRU
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.preprocessing.text import one_hot
from keras.utils import to_categorical
from keras.callbacks import History ,ModelCheckpoint, EarlyStopping
import numpy as np
# %env CUDA_VISIBLE_DEVICES=6
import pickle
# Out:
# Using TensorFlow backend.
# env: CUDA_VISIBLE_DEVICES=6

# %%
train_data = np.load("data/train.data")
test_data = np.load("data/test.data")
print(len(train_data),"個 training 音檔")
print(len(test_data),"個 testing 音檔")
max_frame_length = np.max([len(sample) for sample in train_data])
print("max langth of wav:",max_frame_length)
# Out:
# 45036 個 training 音檔
# 2000 個 testing 音檔
# max langth of wav: 246

# %%
# load caption
with open("data/train.caption","r") as f:
    train_caption = f.readlines()
    train_caption_input = ["<BOS> "+ sent.strip() for sent in train_caption]
    train_caption_target = [sent.strip()+ " <EOS>" for sent in train_caption]
# chinese character level tokenizer
tokenizer = Tokenizer(num_words=None,filters='!"#$%&()*+,-./:;<=>?@[\\]^_`{|}~\t\n', lower=True, split=" ",
                                   char_level=False)
tokenizer.fit_on_texts(train_caption_input + train_caption_target)
print("number of token in train caption:", len(tokenizer.word_index))
input_sequences = tokenizer.texts_to_sequences(train_caption_input)
target_sequences = tokenizer.texts_to_sequences(train_caption_target)
max_length = np.max([len(i) for i in input_sequences])
print("max length:", max_length)

# pad sequence
train_input_pad = pad_sequences(input_sequences, maxlen=max_length)
train_target_pad = pad_sequences(target_sequences, maxlen=max_length)

# build training max
input_matrix = np.zeros((len(train_input_pad),max_length,len(tokenizer.word_index)+1))
target_matrix = np.zeros((len(train_target_pad),max_length,len(tokenizer.word_index)+1))
for i,sent in enumerate(train_input_pad):
    for j, word_ind in enumerate(sent):
        input_matrix[i,j,word_ind] = 1
        
for i,sent in enumerate(train_target_pad):
    for j, word_ind in enumerate(sent):
        target_matrix[i,j,word_ind] = 1
# revert : np.argmax(matrix[1],axis=1)

train_data_pad = pad_sequences(train_data, maxlen=max_frame_length,dtype='float32')

print("encode input shape:", train_data_pad.shape)
print("decode input shape:", input_matrix.shape)
# Out:
# number of token in train caption: 2391
# max length: 14
# encode input shape: (45036, 246, 39)
# decode input shape: (45036, 14, 2392)

# %%
batch_size = 64  # Batch size for training.
epochs = 100  # Number of epochs to train for.
latent_dim = 256
num_decoder_tokens = input_matrix.shape[2]
# Define an input sequence and process it.
encoder_inputs = Input(shape=(None, 39))
encoder = LSTM(latent_dim, return_state=True)
encoder_outputs, state_h, state_c = encoder(encoder_inputs)
# We discard `encoder_outputs` and only keep the states.
encoder_states = [state_h, state_c]

# Set up the decoder, using `encoder_states` as initial state.
decoder_inputs = Input(shape=(None, num_decoder_tokens))
# We set up our decoder to return full output sequences,
# and to return internal states as well. We don't use the 
# return states in the training model, but we will use them in inference.
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_inputs,
                                     initial_state=encoder_states)
decoder_dense = Dense(num_decoder_tokens, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)

# Define the model that will turn
# `encoder_input_data` & `decoder_input_data` into `decoder_target_data`
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=["acc"])
hist = History()
check_save  = ModelCheckpoint("models/model-{epoch:05d}-{val_acc:.5f}.h5",monitor='val_acc',save_best_only=True)
early_stop = EarlyStopping(monitor="val_loss", patience=2)
model.fit([train_data_pad, input_matrix], target_matrix,
          batch_size=batch_size,
          epochs=epochs,
          validation_split=0.05,
         callbacks=[check_save, hist, early_stop])
# Out:
# Train on 42784 samples, validate on 2252 samples
# Epoch 1/100
# 42784/42784 [==============================] - 268s - loss: 2.5902 - acc: 0.6007 - val_loss: 2.1946 - val_acc: 0.6395
# Epoch 2/100
# 42784/42784 [==============================] - 263s - loss: 2.0521 - acc: 0.6570 - val_loss: 1.9260 - val_acc: 0.6711
# Epoch 3/100
# 42784/42784 [==============================] - 261s - loss: 1.8357 - acc: 0.6836 - val_loss: 1.7842 - val_acc: 0.6859
# Epoch 4/100
# 42784/42784 [==============================] - 260s - loss: 1.7173 - acc: 0.6963 - val_loss: 1.6955 - val_acc: 0.7002
# Epoch 5/100
# 42784/42784 [==============================] - 260s - loss: 1.6357 - acc: 0.7048 - val_loss: 1.6438 - val_acc: 0.7051
# Epoch 6/100
# 42784/42784 [==============================] - 261s - loss: 1.5761 - acc: 0.7110 - val_loss: 1.5968 - val_acc: 0.7109
# Epoch 7/100
# 42784/42784 [==============================] - 261s - loss: 1.5271 - acc: 0.7160 - val_loss: 1.5587 - val_acc: 0.7140
# Epoch 8/100
# 42784/42784 [==============================] - 259s - loss: 1.4871 - acc: 0.7198 - val_loss: 1.5350 - val_acc: 0.7172
# Epoch 9/100
# 42784/42784 [==============================] - 259s - loss: 1.4528 - acc: 0.7237 - val_loss: 1.5139 - val_acc: 0.7195
# Epoch 10/100
# 42784/42784 [==============================] - 261s - loss: 1.4225 - acc: 0.7269 - val_loss: 1.4954 - val_acc: 0.7215
# Epoch 11/100
# 42784/42784 [==============================] - 262s - loss: 1.3946 - acc: 0.7297 - val_loss: 1.4732 - val_acc: 0.7256
# Epoch 12/100
# 42784/42784 [==============================] - 263s - loss: 1.3787 - acc: 0.7314 - val_loss: 1.4618 - val_acc: 0.7269
# Epoch 13/100
# 42784/42784 [==============================] - 260s - loss: 1.3464 - acc: 0.7356 - val_loss: 1.4511 - val_acc: 0.7287
# Epoch 14/100
# 42784/42784 [==============================] - 266s - loss: 1.3228 - acc: 0.7383 - val_loss: 1.4359 - val_acc: 0.7303
# Epoch 15/100
# 42784/42784 [==============================] - 261s - loss: 1.3002 - acc: 0.7413 - val_loss: 1.4289 - val_acc: 0.7323
# Epoch 16/100
# 42784/42784 [==============================] - 260s - loss: 1.2791 - acc: 0.7437 - val_loss: 1.4209 - val_acc: 0.7334
# Epoch 17/100
# 42784/42784 [==============================] - 263s - loss: 1.2587 - acc: 0.7465 - val_loss: 1.4162 - val_acc: 0.7342
# Epoch 18/100
# 42784/42784 [==============================] - 263s - loss: 1.2388 - acc: 0.7494 - val_loss: 1.4133 - val_acc: 0.7351
# Epoch 19/100
# 42784/42784 [==============================] - 259s - loss: 1.2207 - acc: 0.7519 - val_loss: 1.4096 - val_acc: 0.7357
# Epoch 20/100
# 42784/42784 [==============================] - 263s - loss: 1.2020 - acc: 0.7541 - val_loss: 1.4052 - val_acc: 0.7370
# Epoch 21/100
# 42784/42784 [==============================] - 260s - loss: 1.1844 - acc: 0.7565 - val_loss: 1.4030 - val_acc: 0.7374
# Epoch 22/100
# 42784/42784 [==============================] - 259s - loss: 1.1674 - acc: 0.7591 - val_loss: 1.4005 - val_acc: 0.7391
# Epoch 23/100
# 42784/42784 [==============================] - 262s - loss: 1.1516 - acc: 0.7613 - val_loss: 1.3974 - val_acc: 0.7381
# Epoch 24/100
# 42784/42784 [==============================] - 260s - loss: 1.1349 - acc: 0.7636 - val_loss: 1.3986 - val_acc: 0.7397
# Epoch 25/100
# 42784/42784 [==============================] - 255s - loss: 1.1190 - acc: 0.7659 - val_loss: 1.4012 - val_acc: 0.7385
# Epoch 26/100
# 42784/42784 [==============================] - 261s - loss: 1.1030 - acc: 0.7682 - val_loss: 1.3992 - val_acc: 0.7410

# %%
# inference (testing)
encoder_model = Model(encoder_inputs, encoder_states)

decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]
decoder_outputs, state_h, state_c = decoder_lstm(
    decoder_inputs, initial_state=decoder_states_inputs)
decoder_states = [state_h, state_c]
decoder_outputs = decoder_dense(decoder_outputs)
decoder_model = Model(
    [decoder_inputs] + decoder_states_inputs,
    [decoder_outputs] + decoder_states)

# %%
inv_tokenizer = {v: k for k, v in tokenizer.word_index.items()}
inv_tokenizer[0] = ""

# %%
tokenizer.word_index["bos"]
# Out:
# 1

# %%
def decode_sequence(input_frame):
    # Encode the input as state vectors.
    max_decoder_seq_length = 20
    states_value = encoder_model.predict(input_frame[np.newaxis,:,:])

    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1, 1, num_decoder_tokens))
    # Populate the first character of target sequence with the start character.
    target_seq[0, 0, tokenizer.word_index["bos"]] = 1.

    # Sampling loop for a batch of sequences
    # (to simplify, here we assume a batch of size 1).
    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict(
            [target_seq] + states_value)
        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_char = inv_tokenizer[sampled_token_index]
        decoded_sentence += sampled_char

        # Exit condition: either hit max length
        # or find stop character.
        if (sampled_char == 'eos' or
           len(decoded_sentence) > max_decoder_seq_length):
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1, 1, num_decoder_tokens))
        target_seq[0, 0, sampled_token_index] = 1.

        # Update states
        states_value = [h, c]
    decoded_sentence = decoded_sentence.replace("eos","")
    
    return decoded_sentence

# %%
test_data_pad = pad_sequences(test_data, maxlen=max_frame_length,dtype='float32')

# %%
answer = []
for i in test_data_pad:
     answer.append(decode_sequence(i))

# %%
inv_tokenizer[1]
# Out:
# 'bos'

# %%
answer
# Out:
# ['我們不可能會有好好的照顧孩',
#  '不用了你們家裡還有一些有空',
#  '不然我們要去找她爸爸媽媽看看',
#  '我們不是要跟他一起去開口嗎',
#  '嬰兒我們要把錢藏起來的時候',
#  '我們要去找她爸爸媽媽是一個',
#  '你們就不知道我們家裡的一切',
#  '你們現在說好好跟妳說這麼多',
#  '我們不是要去找她爸爸媽媽對',
#  '你們不可以讓我們家的感情了',
#  '你們有沒有跟我說一些有一些',
#  '如果我們不是你們母女的心情',
#  '我們不可以讓我們知道的時候',
#  '我們的是不是要跟我一個人情',
#  '如果你們知道了一個人在一起',
#  '不知道該怎麼會這麼做的事情',
#  '不然你們要不要跟我們一起去',
#  '我們不是不是跟我一個人相親',
#  '我一個人在外面向人家道歉是',
#  '我一定要好好照顧身體會不會',
#  '我們都不知道我爸爸爸媽媽在',
#  '不知道該怎麼會這麼做這麼說',
#  '我也不是看到這個人都不知道',
#  '我們不是要去找她爸爸的時候',
#  '我不知道該怎麼會在這裡做人',
#  '如果我們就是不知道該怎麼辦',
#  '我們要不要跟我們一起去相親',
#  '我們是有一個人在家裡的人是',
#  '我們不可以讓他們當我的律師',
#  '你們都不可以去外面拍賣了嗎',
#  '我看看看這些有一個是男朋友',
#  '我們不知道該怎麼會在這裡呢',
#  '我們已經掌握到關鍵的證據了',
#  '如果你們不知道我們在一起嗎',
#  '如果有一個人同樣的人在身邊',
#  '我們不知道該怎麼會成這種事',
#  '我看你們一定會好好照顧孩子',
#  '不知道該怎麼會這麼做的事情',
#  '不然我們要把錢交給我們一點',
#  '現在是我們的事情都是不甘心',
#  '不知道我們家裡不會再給我們',
#  '你們不知道我爸爸爸媽媽不是',
#  '因為我們一個人在一起吃飯時',
#  '不知道該怎麼會在這裡做什麼',
#  '一定要為了一個人在家裡面對',
#  '如果我們不是說這個好好照顧',
#  '你們不可以讓我們一點都不好',
#  '妳應該可以去找他們交往過去',
#  '現在妳們不是要去找我們一點',
#  '我們不是要跟曉萍在一起吃飯',
#  '我們不是要跟她一起去相親嗎',
#  '不知道該怎麼會這麼做的事情',
#  '我們也不會有人在身邊找方法',
#  '我們已經跟楊先生說好好照顧',
#  '你們不可以跟你們一起去醫院',
#  '我們不是不是跟我一個人在家',
#  '我們不是要跟她一起去開口嗎',
#  '我們也不是說過這種話都說了',
#  '我跟你們好了一起去開會開酒',
#  '我們已經跟妳一起去找一個人',
#  '我們不可以當時間公司上班了',
#  '你們不知道該怎麼會這麼做呢',
#  '如果你們知道我們一起出去嗎',
#  '我們已經跟妳說過去的時候了',
#  '如果妳願意知道我們家的孩子',
#  '我們不是說這些話跟文隆一起',
#  '如果你們夫妻說這種人才能力',
#  '如果妳知道在這裡等我一會兒',
#  '我看你們不可以讓我們相親嗎',
#  '我們的是不是跟你在一起吃飯',
#  '我們一定會好好照顧自己身邊',
#  '我們一定會好好照顧冠軍的孩子',
#  '如果我知道妳現在在哪裡了嗎',
#  '我們不可以再用了解他的個性',
#  '我們不是不是跟美純一個人在',
#  '如果你們知道我們一起去開口',
#  '是我們的孩子已經跟你在一起',
#  '不用這裡的東西都是吃不下的',
#  '我們已經跟妳在一起去開會兒',
#  '我們知道這個人在外面在身邊',
#  '我們不是要跟他一起去開口嗎',
#  '我也不是說過這種話都說清楚',
#  '不知道該怎麼會在這裡做什麼',
#  '如果我知道妳不是說得很清楚',
#  '我們不可以讓他們在這裡相親',
#  '不知道我們是不是要離開我了',
#  '我也不是要跟慧君一起去開口',
#  '如果你們不知道我們在這裡等',
#  '我們不可以去找他們的親生母',
#  '否則我們家裡陪妳一起去醫院',
#  '我們不可能跟妳一起去開口嗎',
#  '我們不是要跟她一起去相親嗎',
#  '我們不可以去找他們吃飯一點',
#  '不過去看看我們是我的親朋友',
#  '我們不可以讓他們在外面試試',
#  '我們也不是說過這種話都說了',
#  '我們要去找她爸爸媽媽是一個',
#  '我們都不知道該做的感情和事',
#  '我不知道該怎麼會在這裡做人',
#  '我們已經跟爸爸爸爸在一起吃',
#  '我們應該是你們去找他們一樣',
#  '我們不是要跟他一起去開口嗎',
#  '如果你們不知道我們在一起去',
#  '如果妳現在在這裡做一個人情',
#  '你們知道知道我們在想起來了',
#  '我們不是要去找她爸爸的公司',
#  '如果你們有一個人在家裡面前',
#  '我不可以讓我們跟我們一起去',
#  '我們不知道該做的感情都不好',
#  '不知道該怎麼會在這裡做什麼',
#  '我看到文隆哥已經跟你說過了',
#  '不知道該怎麼會這麼做的事情',
#  '你們不是要跟她一個人在一起',
#  '我們不是要跟曉萍一起吃一點',
#  '剛才不是你們母女孩子不知道',
#  '現在是我們的事情已經很好了',
#  '我們的家道謝謝你們先去找他們',
#  '我們不可能會讓我們一起出去',
#  '我們不可能是為了一個人同事',
#  '如果妳不知道該怎麼做成這樣',
#  '不是你們知道我們家裡的一切',
#  '我們也不會有事要向妳介紹所',
#  '你們就好了解釋一些新開始開',
#  '我們不是要跟文隆一起吃好了',
#  '你們不知道我們一定會盡力吃',
#  '我們不可以去了解了解了一間',
#  '我也不可能跟我爸爸的好朋友',
#  '我們要去找她爸爸媽媽是一個',
#  '我們不是要去找她爸爸媽媽對',
#  '我們不是一個人在一起吃飯嗎',
#  '我們不可以去醫院看我們一次',
#  '我們不是這個人在一起吃飯時',
#  '我們去哪裡了解一個人的身分',
#  '我們一直都會保護他們的事情',
#  '不是我們的事情搞得這麼嚴重',
#  '我們不可以讓他們當我的律師',
#  '不知道該怎麼會在這裡做什麼',
#  '我們不是要去找她爸爸的是主',
#  '不知道該怎麼會在這裡做什麼',
#  '你們不可以讓我們一起去看看',
#  '我們不是不是要跟我一個人的',
#  '我們不是說過這種話都沒有說',
#  '現在就可以說到這個孩子的事',
#  '我們不是要跟曉萍一起去看看',
#  '我們也不是說過這種話都說了',
#  '這間公司的事業都是你的男人',
#  '我們已經跟楊先生說好好照顧',
#  '我們是應該是我們先去找他們',
#  '我們要不是一個人在外面的人',
#  '不知道該怎麼會在這裡做什麼',
#  '不是你們母女一直接受我的事',
#  '我們也不可能答應我的男朋友',
#  '如果我跟她爸爸爸媽媽在一起',
#  '如果你們知道我們一起去相親',
#  '我看看到這個人在外面對方小',
#  '不然我們不是要去找她爸爸媽',
#  '如果妳們不知道我們一起出去',
#  '我們不可以讓他們在這裡相親',
#  '不過我們就可以當一個人犯了',
#  '否則我們會兒子會在這裡等我',
#  '不知道該怎麼會這麼做的事情',
#  '我們去看醫院不是說的是應該',
#  '我也不可以讓他們擔心不好嗎',
#  '不然我們已經跟楊先生說好了',
#  '我們不可以跟他們一起去外面',
#  '我們是不是跟我一個人在一起',
#  '否則我們現在是你們的女朋友',
#  '你們不可以讓我們知道這件事',
#  '我的是不是應該跟我糾纏不了',
#  '我們不是要跟他一起去開口嗎',
#  '我們不可以讓我們好好照顧身',
#  '不然我們不是要跟文隆一起吃',
#  '我們不可以讓他們母女的心情',
#  '我們有沒有看到我們的聚會兒',
#  '我們也是為了一個人的身分證',
#  '如果你們有什麼事情都沒有事',
#  '不知道該怎麼可能這麼做生意',
#  '這張美純已經跟曉萍在一起了',
#  '不是我們要把錢交給我們吃了',
#  '不知道該怎麼會這麼做的事情',
#  '我們都不可以去找他們一起去',
#  '我們是不是要跟我一個人在家',
#  '我們不可以讓我們家的時候吃',
#  '不知道該怎麼會這麼做的事情',
#  '我們可以去找他們一點都不起',
#  '我們是一個人犯了的事情一堆',
#  '現在你們不是要去找她爸爸媽',
#  '不知道妳現在已經沒有怎麼了',
#  '不知道該怎麼會這麼做的事情',
#  '為什麼跟我爸爸爸爸媽媽回來',
#  '我們不可以讓他們母女的心情',
#  '我們去看看爸爸媽媽在一起吃',
#  '我們已經跟楊先生說好幾倍了',
#  '我們要不是一個人在外面對象',
#  '不是我們要把錢交給我們吃飯',
#  '不知道該怎麼會這麼做的事情',
#  '我們先去找她爸爸媽媽在一起',
#  '我一直想當我們家的親朋好',
#  '我們不可能會讓我們一起吃飯',
#  '我已經跟我說了一些都沒有用',
#  '不知道我們家有一個人在一起',
#  '現在就是不知道該怎麼做成了',
#  '我們不可能會讓我們在一起吃',
#  '我們是不是跟曉萍一起去相親',
#  '我們不是要跟她一起去找一點',
#  '不用了爸爸爸爸爸媽媽回來了',
#  '現在是我們的事情都不知道嗎',
#  '一定會好好照顧你們家的孩子',
#  '你們不可以讓我們好好照顧他',
#  '我們去找她爸爸媽媽是一個人',
#  '我們不知道該怎麼會在這裡呢',
#  '我們的兒子好好照顧好照顧孩',
#  '現在這裡是你們的親生的女朋',
#  '現在就是不是你們母女孩子了',
#  '不知道該怎麼會這麼做的事情',
#  '不可以讓妳們母女一點心情嗎',
#  '我們去找那些錢跟人家一起吃',
#  '不是你們知道我們一起去相親',
#  '我們不可以讓他們在外面試試',
#  '如果你們不知道他們在一起嗎',
#  '要不是我們一個人在一起吃飯',
#  '剛才不然我們要好好照顧曉萍',
#  '我們要跟她一起去外面做生活嗎',
#  '我們不是要跟他一起去開口嗎',
#  '如果妳知道在想那裡找我一個',
#  '你不知道我爸爸爸爸媽媽不好',
#  '我們不可以讓我們擔心的好嗎',
#  '你們不知道我們一起去外面試',
#  '現在去找他們一個人在一起嗎',
#  '我也不知道我爸爸爸媽媽不好',
#  '你們不可以讓他們知道這件事',
#  '你怎麼可以說我這麼做的事情',
#  '我們是一個人在外面的人相親',
#  '我們已經跟他們一起去開口戶',
#  '我們都不可以去外面休息一會',
#  '我們去找他們一起去找方慶堂',
#  '你有沒有跟她一起去買一些菜',
#  '所以我們先去跟妳爸去看醫生',
#  '我們就可以當然要好好照顧她',
#  '妳們不可以讓他們母女生氣嗎',
#  '現在我們一定會好好照顧孩子',
#  '一個人要跟我們一起去找一個',
#  '不過你們母子不會有事的是我',
#  '我也不知道該怎麼會在這裡鬧',
#  '我們已經跟妳一起去找一個人',
#  '我們不是說過這種話都說出口',
#  '不知道該怎麼會在這裡做什麼',
#  '我們已經跟妳一起去看看醫生',
#  '如果你們不知道我們一起出去',
#  '我不可以讓妳們母女的心肝寶',
#  '你們不可以讓我們好好的地方',
#  '我們都已經跟文隆哥的關心了',
#  '我們的是不是應該是我告訴你',
#  '我們不是要跟他一起去開口店',
#  '我們去找那些資料跟妳在一起',
#  '你看看他們不要跟我們一起去',
#  '我們要知道一個人會在一起嗎',
#  '我們的家裡不可以吃一點點了',
#  '我們不是不是跟你們一起去嗎',
#  '我們是一個人在外面的人相親',
#  '而且我們不可能會這麼做的事',
#  '我們不可以讓他們在一起出面',
#  '不知道該做的是三個小三一樣',
#  '不知道該怎麼會在這裡做什麼',
#  '我們不是要跟曉萍一起去開口',
#  '我們都不可能跟我說好好好了',
#  '不用我們要去找昭華打電話嗎',
#  '我們不可以讓他們在外面上班',
#  '我們不是要去找她爸爸媽媽是',
#  '我們已經跟妳一起去找一個人',
#  '我就不知道該怎麼說得這麼好',
#  '我們也算是公司的員工作上班',
#  '你們不知道我們家裡了一起吃',
#  '我們不知道他們是我的親朋友',
#  '我去找我們一個人情緒不穩定',
#  '我們去找他們一些新娘的身體會',
#  '我們已經跟妳在一起去開門口',
#  '不知道該怎麼會在這裡做什麼',
#  '我們不是不是跟美純一起去嗎',
#  '我們是不是跟妳一起去開口嗎',
#  '一定要為我們一個人在一起嗎',
#  '不是我們不可以跟我們一起去',
#  '我想跟曉萍一起去找方慶堂嗎',
#  '我看看到這個人是你的男朋友',
#  '因為我們一定會盡力不太太過',
#  '我們不可以讓他們在這裡等我',
#  '你們不可以讓我們擔心不好嗎',
#  '你們不知道我爸爸爸在一起吃',
#  '這種人應該是你們的女朋友嗎',
#  '所以我們不可以去找他們一起',
#  '我們也不是要跟曉萍在一起吃',
#  '我們已經跟他一起去找一個人',
#  '不知道該怎麼會這麼做的事情',
#  '這張美純的孩子已經跟你在了',
#  '我們不可以讓他們在這裡相親',
#  '我們不是要去找她爸爸媽媽是',
#  '不要我們家的事情都會不會了',
#  '我們去醫院看醫生說的是什麼',
#  '我們不可以讓他們母女的心情',
#  '我們不是有個性子的人在一起',
#  '剛才不是說到這個人都不知道',
#  '我們這間房子是我的公司上班',
#  '我說你們有沒有說過來的時候',
#  '而且我們要把錢藏起來的時候',
#  '你們不知道我爸爸爸媽媽回來',
#  '我們已經跟妳一起去找一個人',
#  '一定要把他們找到一個人試吃',
#  '不是我們在一起吃飯都會嗆到',
#  '我們已經跟妳一個人在一起人',
#  '但是我們不知道該怎麼做成這',
#  '不知道該怎麼會在這裡做什麼',
#  '我們不可能跟我一起去看看看',
#  '一定要救我的孩子是我的孩子',
#  '你們不可以讓我們擔心不好嗎',
#  '我們不是要跟我一個人在一起',
#  '如果妳們不知道在一起出面前',
#  '我們不是一個人相親的男朋友',
#  '一定要知道我們家的事情一堆',
#  '你們不可以讓我們知道的男人',
#  '我們一個人在外面會受到傷害',
#  '我們已經跟他一起去就好好了',
#  '我們的家裡是一個人在一起嗎',
#  '一定要為了一個人在家裡面對',
#  '不是我們不知道該怎麼會在忙',
#  '我們不可以去了解了解的感情',
#  '不是我們的事情搞得這麼嚴重',
#  '如果你們有沒有跟我說一些話',
#  '你們不可以讓我們擔心不好嗎',
#  '你們有沒有跟我說一些有一些',
#  '而且不可以讓我們母女的心情',
#  '我們不可以跟文隆哥交往好事',
#  '我們不可以讓他們知道的時候',
#  '不要跟她一起去外面那麼多錢',
#  '如果妳跟慧君她爸爸的是共犯',
#  '我一定要相信我們的親朋好友',
#  '如果妳不知道在這裡做什麼事',
#  '我也不可能會讓我們的親朋好',
#  '不知道該怎麼會這麼做的事情',
#  '不過我們不是要去找他們一趟',
#  '我們也不知道該怎麼做成這樣',
#  '如果你們知道他是我們的孩子',
#  '如果妳知道知道我在一起出面',
#  '是不是我們在這裡等我一會兒',
#  '不是我們的孩子已經離開了嗎',
#  '如果真的想到我們家的感情是',
#  '待會兒就可以把他們回去吃飯',
#  '我們要先去倉庫拿給我吃好了',
#  '如果妳知道知道我們在家裡面',
#  '不知道該怎麼會在這裡做什麼',
#  '我們已經跟楊先生說好幾倍了',
#  '不知道該怎麼會在這裡做什麼',
#  '我們不可能是我們先去找文進',
#  '這間公司的事業都找到一個人',
#  '我看看他們有一個人在家裡嗎',
#  '我們已經跟楊先生說好幾倍了',
#  '不知道該怎麼會這麼做的事情',
#  '現在你們不知道我們是不是嗎',
#  '我們不是要跟她一起去開口店',
#  '我們先去找她爸爸媽媽在一起',
#  '一點都不知道該怎麼做這麼多',
#  '我們去看看他是我的公司是我',
#  '我一個人為了一個人同住一切',
#  '我也不可以讓他們好好的照顧',
#  '不知道該怎麼會在這裡做什麼',
#  '如果妳想到這個孩子的生活著',
#  '我們要有一些有一些新的是公',
#  '你不知道我爸爸爸爸媽在擔心了',
#  '你們不可以讓我們一直罵我們',
#  '我們公司的是公司的員工作時',
#  '但是我們不是要去找他們一點',
#  '我們是否不是跟妳一起去開口',
#  '我們現在是爸爸的公司上班了',
#  '而且我們可以找到一個人相親',
#  '我們已經跟楊先生說好幾倍了',
#  '我看你們一次不是一般人家的',
#  '我們不知道會不會惹上那種人',
#  '我看看看到什麼不是我的孩子',
#  '我們是一個人在外面的人相往',
#  '不然我們要去廟裡跟她說一些',
#  '我們不可能跟妳說了一些人情',
#  '如果妳不知道該怎麼做成這樣',
#  '我們不是要去找她爸爸去逛街',
#  '我們不是一個人在外面的地方',
#  '我們不是要跟曉萍一起去一趟',
#  '我們不是要去找她爸爸去逛街',
#  '你們現在說到了解了解了一個',
#  '我們不是不是跟我一起去看看',
#  '不知道該怎麼會這麼做的事情',
#  '我們也不會有事要向妳介紹所',
#  '我們也不會跟文隆一起去開口',
#  '不要跟我們一起去外面拍賣了',
#  '不知道該怎麼會在這裡做什麼',
#  '但是我們不可以讓他們在一起',
#  '你們不知道我們家都不知道了',
#  '我們不是要跟慧君的爸爸一樣',
#  '我們是不是應該知道我的孩子',
#  '我們不可以讓他們當我的孫子',
#  '如果你們不知道我們在一起吃',
#  '如果你們不知道我們在一起家',
#  '我們要不是一個人在外面對象',
#  '我們就是不是跟我一個人在家',
#  '如果妳不知道該怎麼做成這樣',
#  '現在我們已經跟楊先生說好了',
#  '我們是不是要跟我一個人在家',
#  '我們不是一個人在外面的人是',
#  '我們不可以讓我們一起去找人',
#  '你們不可以讓他們在這裡等我',
#  '我也不知道我爸爸爸在一起吃',
#  '我也不知道我會在這裡做什麼',
#  '難道你們一定會盡力不舒服嗎',
#  '如果不知道我們是有一個律師',
#  '我們不可以去找他們的親生母',
#  '不是你們母女一直在一起吃飯',
#  '不知道該怎麼會在這裡做什麼',
#  '我們不知道該怎麼會這麼做呢',
#  '我們已經跟楊先生說好幾倍了',
#  '我們不是一個人在一起出面前',
#  '我們不知道該怎麼會在這裡呢',
#  '我也不可以讓他們擔心不好意',
#  '我們不是要跟曉萍一起吃一點',
#  '你們不知道該怎麼會在這裡呢',
#  '我們也不是說過這種話都說了',
#  '我們不可以讓他們當我的律師',
#  '你們不知道我爸爸爸爸媽很好',
#  '我已經跟她一起去找一個人情',
#  '你們有一個人在外面有人在想',
#  '我們不是要去找她爸爸的時候',
#  '我們要去找她爸爸媽是好是我',
#  '我們也不知道文隆哥交往就好了',
#  '不知道該怎麼會在這裡做什麼',
#  '你們怎麼可以說我們有沒有事',
#  '我看你們是不是要跟我一起去',
#  '我也不知道該怎麼會在這裡鬧',
#  '我們去找那些錢給我一個人情',
#  '不是有一個人在家裡面對不起',
#  '如果我們有沒有跟他說在一起',
#  '我們不是要把錢交給我們一點',
#  '如果你們不知道他們在一起嗎',
#  '我們的是不是要跟我們一起去',
#  '我們不是要跟曉萍一起去相親',
#  '我們要去找我爸爸爸爸是公司',
#  '我們的是不是跟我一個人在家',
#  '我們去找一些人家的事情和大',
#  '不知道該怎麼會在這裡做什麼',
#  '我們不知道該怎麼向妳借給他',
#  '你們不可以讓我們擔心不好嗎',
#  '不然我們要跟他一起去開口笑',
#  '我看看你們是否是我們先走了',
#  '否則真的會不會讓你們知道嗎',
#  '不然我們去找他們一點時間嗎',
#  '如果你們知道我們一起去開口',
#  '我們不可以讓他們在外面上班',
#  '我們就是不是跟你們一起去嗎',
#  '如果妳不知道該怎麼做成這樣',
#  '你們不可以讓我們一起去開口',
#  '難道我們就好了解決問題的事',
#  '我看到妳不知道會不會放手上',
#  '我們不可以讓他們在外面上班',
#  '如果你們知道我們一起去相親',
#  '我們是不是要跟我一個人在家',
#  '我們也不會再說這些話的好朋',
#  '我們不是不是跟我一個人在家',
#  '我也不知道爸爸的人在這裡了',
#  '我們已經跟他們一起去開口戶',
#  '我們應該是爸爸爸爸的咖啡廳',
#  '我們要去找她爸爸媽媽是一個人',
#  '我們已經跟他說話不是我的責',
#  '不是我們在一起去找我們一點',
#  '如果妳不要跟他們一起去一樣',
#  '我們就是有一個人在家裡面對',
#  '我們不是一個人在外面的人是',
#  '不知道該怎麼會在這裡做什麼',
#  '你們的是不是我們的女朋友嗎',
#  '你們在前面前面還有一個機會',
#  '我們也不是說過這種話都說了',
#  '妳也不知道我們一起去外面試',
#  '如果我不知道該怎麼說這麼說',
#  '我們不是不是跟我一起去一趟',
#  '我們已經跟他一起去找方慶堂',
#  '我們要不要把錢交給我們吃飯',
#  '如果你們不知道我們在一起家',
#  '不知道該怎麼會在這裡做什麼',
#  '我們不是不是跟你一起去哪裡',
#  '一定會好好照顧冠軍的孩子呢',
#  '你們不可以讓他們母女的孩子',
#  '我們不知道該做的感情都不好',
#  '我們已經跟楊先生說好好照顧',
#  '我們已經跟楊先生說好幾倍了',
#  '我一定會知道我們一起吃飯時',
#  '現在我們不知道該怎麼做生意',
#  '我們也是有一個人在外面的人',
#  '我們去找她爸爸媽媽是一個人',
#  '一直接著不是我們公司的事情',
#  '我們不是要跟她一起去開口久',
#  '妳說過我這個人情不可以失去',
#  '我們已經跟楊先生說好幾倍了',
#  '我們不是要跟她一起去找一點',
#  '我們要不要跟我們一起去相親',
#  '不是你們想當我們家的親朋友',
#  '我們也不知道我爸爸爸媽離婚',
#  '我已經跟楊先生在一起出面了',
#  '我們都不會跟著離婚的會不會',
#  '我看看看到這個人在外面前面',
#  '我們要不是一個人犯了的罪人',
#  '如果我們就是不是你們的女兒',
#  '我們不可以讓他們母女的一樣',
#  '如果妳知道知道我是一個人的',
#  '我也不知道該怎麼會在這裡呢',
#  '我們不是要跟他一起去開口嗎',
#  '不知道該怎麼會有這個孩子呢',
#  '是否知道我們家的事情都不了',
#  '不過我們可以當一般人的身分',
#  '為我在外面的人已經沒有很多',
#  '我們不是說好好照顧我們家解',
#  '你們要不要把錢交給我們吃了',
#  '我們不可以讓妳爸爸爸不知道',
#  '我們不是要跟他一起去開口嗎',
#  '如果我們先去倉庫拿東西給你',
#  '我們已經跟楊先生說好好照顧',
#  '我也不可以讓妳好好照顧孩子',
#  '我們是應該跟他們一起去一趟',
#  '這張美純已經跟你們一起去了',
#  '我看你們去哪裡跟我一個人情',
#  '你們不可以跟我們一起去看看',
#  '我們不可以去外面拍賣了一點',
#  '我們不可能跟我們一起去開口',
#  '現在你們不知道他們在一起去',
#  '不知道該怎麼會在這裡做什麼',
#  '我們不可以跟妳爸爸的腳受傷',
#  '你們不可以讓我們擔心這些話',
#  '不知道該怎麼會在這裡做什麼',
#  '如果我們不可以讓人家認識她',
#  '我看你一個人要跟我一起吃飯',
#  '我們不是要去找她爸爸媽媽是',
#  '你們不知道我們在想起來不是',
#  '我們不是說了一個人在外面嗎',
#  '我看看看妳是我們的親朋好友',
#  '一直接著我們的事情是大的事',
#  '不過我們已經跟楊先生說好了',
#  '我們不是要跟曉萍在一起吃飯',
#  '這是我們應該是我跟妳說過了',
#  '我們不是要跟曉萍在一起吃飯',
#  '你們有沒有看到哪裡有瘀青的',
#  '我們不可以讓他們知道的時候',
#  '我們不可以讓他們在這裡相親',
#  '你們不知道該怎麼會這麼做呢',
#  '如果你們現在已經跟你在一起',
#  '如果你們不知道該怎麼做成這',
#  '否則不可以讓他們母女朋友了',
#  '如果你們想到這個人在家裡嗎',
#  '如果妳知道知道我們家的手機',
#  '我們不可以讓他們當我的律師',
#  '不可以讓你們在這裡做什麼事',
#  '你們不知道我們家說得很清楚',
#  '如果妳知道知道我們家的時候',
#  '我們是應該是我跟慧君的爸爸',
#  '我們可以跟文隆哥交往就好了',
#  '我們不可能會讓我們一起出來',
#  '我們的不是不可以這麼做的事',
#  '我們的是不是跟妳在一起吃飯',
#  '我們不可以當時間公司上班了',
#  '現在妳們這麼做就是這麼做的',
#  '我們是應該知道我們在討論婚',
#  '我們這間公司上班是好好處理',
#  '不是你們要把錢交出去的事了',
#  '我們不是不是跟你們一起去嗎',
#  '我們不知道該怎麼會在這裡呢',
#  '我們已經跟妳說好好照顧自己',
#  '否則我們是不是跟你在一起嗎',
#  '現在是你們的孩子已經很清楚',
#  '如果妳不知道該怎麼做這麼做',
#  '我們已經跟妳在一起出國度假',
#  '如果妳不知道該怎麼做成這樣',
#  '我們不可能會讓我們好好照顧',
#  '如果妳想跟我們一起去找方曉',
#  '我們是一個人在外面的人在身',
#  '我們不可以去外面當初我相信',
#  '而且我們可以去找他們一起吃',
#  '我看你們不要跟我們一起去外',
#  '現在我們一個人在一起出面前',
#  '我們去找她爸爸爸媽是好好照',
#  '我們有沒有跟我爸爸的兒子好',
#  '我們不是說了一個人在家裡嗎',
#  '我們這間房子是我的公司上班',
#  '我們不是要跟曉萍一起吃一點',
#  '我們不知道我們一定會好好照',
#  '不用了我們家的是三個大律師',
#  '不然我看你們不要跟我一起去',
#  '我們不可以去找他們一點時間',
#  '我們不可以讓他們當然不知道',
#  '你們怎麼可以說到這個好人家',
#  '如果你們真的想到我們去找他',
#  '我們不可以跟他一起去就對了',
#  '我們的是不是說到這個男人了',
#  '我們不可能跟我們一起去相親',
#  '我們不可能跟我們一起去開口',
#  '不要我們要去找他們一點時間',
#  '我們是不是要跟我一個人在家',
#  '不然我們已經跟他們一起去外',
#  '剛才不可以讓我們母女朋友嗎',
#  '妳們要知道我們家的手機會受',
#  '我們已經跟妳一起去找一個人',
#  '你們不可以讓我們好好照顧家',
#  '我們的是不是跟我一個人在家',
#  '不要跟她一個人在家裡面對嗎',
#  '如果我們就不會讓你們擔心了',
#  '如果我跟慧君她爸爸的孩子了',
#  '我們也不知道該怎麼會在這裡',
#  '我們不是要跟曉萍在一起吃飯',
#  '我們要去找她爸爸媽媽是一樣',
#  '如果妳想到這個孩子的生活著',
#  '我們不可以去找他們的好朋友',
#  '如果你們一個人在一起我會兒',
#  '我們是不是跟妳一起去開口嗎',
#  '你不知道我爸爸爸媽媽在一起',
#  '我們不可以去找他們一點時間',
#  '不知道該怎麼會這麼做的事情',
#  '不是我們的事情都不知道了嗎',
#  '我們不可以當時間公司上班了',
#  '如果我們去找他們一起去開口',
#  '我們是不是跟曉萍在一起吃飯',
#  '我們是應該是我跟慧君的關係',
#  '不知道該怎麼會變成這樣對吧',
#  '如果你們不可以讓我們一起去',
#  '不知道該怎麼會這麼做的事情',
#  '我們要不是一個人在外面的人',
#  '我們已經跟他一起去找一個人',
#  '不是我們不可以去找他們聊',
#  '我們都不可以跟文隆哥的關係',
#  '你們夫妻一樣了一下次我一點',
#  '我們不是要去找她爸爸媽媽是',
#  '是我們可以跟妳一起去看看爸',
#  '我們不是要跟曉萍一起出國外',
#  '不是我們要把錢交給我們一點',
#  '我們不是要跟曉萍一起去相親',
#  '你們現在說什麼要不要這麼做',
#  '以為你們要不要相親的親朋好',
#  '我們不是一個人在一起出面前',
#  '如果我們不知道他們在一起嗎',
#  '我們要不是一個人相親的生活',
#  '你們不可以讓我們母女的心情',
#  '既然我們不可以去找他們一樣',
#  '我們不是不是跟我一個人在家',
#  '不知道該怎麼會在這裡做什麼',
#  '我們的是不是要跟妳一起去嗎',
#  '不過妳也是為了你們的女朋友',
#  '我們不可能會讓我們好好保養',
#  '我們不要跟我們一起去開口閉',
#  '如果你們不知道我們在這裡等',
#  '我們也不可能會讓我們的時候',
#  '不要跟她一個人在家裡面對嗎',
#  '你們去醫院看醫生說得不對嗎',
#  '我們要不是一個人在外面的人',
#  '你們不要跟我們一起去相親嗎',
#  '',
#  '我們不是要跟她一起去開一趟',
#  '剛才不可以讓我們母女朋友嗎',
#  '你們不知道我們在一起出來了',
#  '我們不是要跟曉萍在一起吃飯',
#  '如果你們知道這個人在家裡嗎',
#  '我一定會是我們一個人在身邊',
#  '如果我跟慧君一起去看看醫生',
#  '你們不可以讓他們母女的心情',
#  '我們也不可能跟我爸爸的兒子',
#  '我也不知道該怎麼會在這裡鬧呢',
#  '如果你們不知道我們在擔心了',
#  '不知道該怎麼會這麼做的事情',
#  '我的是三個大哥跟在一起吃飯',
#  '我不知道該怎麼會在這裡做人',
#  '我們不知道該怎麼會成這樣呢',
#  '如果我們不是要去找他們一起',
#  '我們不是要跟她一起去相親人',
#  '我們也不會再跟文隆一起吃飯',
#  '我也不知道我爸爸爸媽媽回來',
#  '我們的是公司的事情都有沒有',
#  '如果你們有沒有跟我一起去嗎',
#  '剛才不是說你們母子不會放棄',
#  '你們的是不是不知道我的孩子',
#  '你們不知道我們在這裡等文進',
#  '現在我們已經跟你們一起去了',
#  '我們不是說過這種話都說清楚',
#  '我們要去找她爸爸媽媽是一個',
#  '我們不知道該怎麼會在這裡呢',
#  '我們已經跟楊先生說好幾倍了',
#  '我們不可以讓他們在外面對方',
#  '我們去找那些錢跟我們一起吃',
#  '我們不是有人在一起吃飯時間',
#  '我們去找那些錢跟人家一起吃',
#  '否則我們不可以讓他們知道嗎',
#  '如果你們不知道我們在這裡等',
#  '以後我們不可以去找他們一點',
#  '我們是應該是我跟慧君的爸爸',
#  '我們也不是說過這種話都說了',
#  '如果你們不是要去找她爸爸媽',
#  '如果你們不知道他們一起出去',
#  '如果你們一個人在這裡做什麼',
#  '不要我們家的事情都會不舒服',
#  '不是你們母女不是我們的孩子',
#  '如果妳真的不知道該怎麼回事',
#  '妳不知道該怎麼會在這裡嘆氣',
#  '我先去找她們一點時間要休息',
#  '我們不是要跟曉萍一起吃一點',
#  '不然我們不可以讓我們擔心了',
#  '如果你們不知道我們家裡的事',
#  '你不知道我爸爸爸媽媽在一起',
#  '你們不可以讓我們好好的地方',
#  '我們已經跟楊先生說好好照顧',
#  '我們不可以讓他們在外面試試',
#  '我們不可能跟我一起去就好了',
#  '我們是應該是我跟妳說好了嗎',
#  '我們要不是一個人在外面對象',
#  '我們不知道該怎麼會在這裡呢',
#  '我們已經跟他一起去找一個人',
#  '我們的是有一個人在外面的人',
#  '你們不知道該怎麼會這麼嚴重',
#  '如果妳不知道該怎麼做成這樣',
#  '而且我看到文隆哥都不知道了',
#  '否則我們是否該進去看醫生說嗎',
#  '不是你們知道我們家的女朋友',
#  '我們不知道該怎麼會在這裡想',
#  '你們有沒有看到我們的時候了',
#  '不可以去你們的事情不是我的',
#  '是一個是尚未有人在身邊的人',
#  '你們知道我們一定會盡量失去',
#  '我們也不是說過這種話都說了',
#  '我們已經跟他們一起去開口戶',
#  '我們不可能會讓我們的親朋友',
#  '你不可以讓我們跟我們一起去',
#  '現在妳們要知道我們家的時候',
#  '剛才不是我們跟曉萍在一起嗎',
#  '這是我們的事情搞得這麼嚴重',
#  '這麼說的是你們的女朋友一樣',
#  '我已經跟她一起去找我一個人',
#  '我們不知道該怎麼會在這裡呢',
#  '如果你們不是要去找她爸爸媽',
#  '我們是一個人在外面的人在場',
#  '如果妳說過去就好了解決問題',
#  '我們不知道該做的是三個小孩',
#  '心想跟你們一個人在一起出團',
#  '我看看你們不是說要對付出道',
#  '不是我們先去找他們交往過去',
#  '不是我跟慧君說我們有一個人',
#  '我們不是想跟曉萍一起出國外',
#  '我們不可以讓他們母女一起去',
#  '你們不好好好照顧家庭上班了',
#  '我們不是要去找她爸爸媽媽是',
#  '不知道該怎麼可以這麼說的話',
#  '我們不可以讓他們相親的親生',
#  '你們的事情都不知道該怎麼辦',
#  '不可以讓妳們知道我們的時候',
#  '不知道該怎麼向妳借錢給她們',
#  '我們不是要跟曉萍一起去開口',
#  '而且不可以讓他們在這裡等我',
#  '我們這個是你們的人在一起吃',
#  '我們不是要跟他一起去開口嗎',
#  '我們要去找她爸爸媽媽是一個人',
#  '如果你們不知道我們一起出去',
#  '我們已經跟曉萍在一起吃飯了',
#  '我們去找她爸爸媽媽是一個人',
#  '我們不是不知道該做的那麼多',
#  '不知道該怎麼會在這裡做什麼',
#  '我們不可以讓他們母女的心情',
#  '現在你們不知道在裡面那裡是',
#  '我們不可以讓妳好好照顧曉萍',
#  '我們是一個人在外面的人不是',
#  '我們不知道該怎麼會這麼做呢',
#  '我們不可以讓他們母女的心情',
#  '不過我們可以當一個人生活的',
#  '而且我看到妳們家裡不舒服嗎',
#  '我們不可以讓他們母女的心情',
#  '現在是你們的女孩子在身邊坐',
#  '我們已經跟妳一起去找一個人',
#  '你們不知道我們是有一個律師',
#  '不要跟她一直接著我們的時候',
#  '現在你們不知道我們是不知道',
#  '我們的是不是跟妳在一起吃飯',
#  '我看看你們不是要去找方曉萍',
#  '我們不是要跟她一起去相親嗎',
#  '我們夫妻相信我們家裡的一切',
#  '我們不知道該怎麼會成這樣呢',
#  '你們不好好照顧家庭上班時間',
#  '不過我們就可以當然要保護妳',
#  '你們不可以讓他們一起去開口',
#  '現在這裡等我們一次就是一樣',
#  '不用我們要去找他們一點時間',
#  '不然我們要去找他們一點時間',
#  '這張美純已經跟你們一起去了',
#  '我們不可能會讓我們一起出去',
#  '妳看看到這個人都在外面對方',
#  '是你們家裡的事情都是我不好',
#  '如果我不是你們母女不一樣吧',
#  '我已經跟妳一個不會的一直罵',
#  '如果我們不可以讓我們母女兒',
#  '我們不是不是跟你一起去哪裡',
#  '不知道該怎麼會在這裡做什麼',
#  '不是我們是為了一個人在身邊',
#  '不要我們父子一起去找我一點',
#  '你們也不知道我爸爸爸媽媽在',
#  '我們不是要跟曉萍一起去開口',
#  '我們不是要去找她爸爸媽媽是',
#  '我們不可能會讓我們一起出來',
#  '如果你們有沒有想到我們家的',
#  '你們不知道我爸爸爸媽很辛苦',
#  '待會兒我們先去找他們去看看',
#  '不要跟她一起去旅遊公司纏我',
#  '',
#  '如果妳有什麼事都不知道該做',
#  '我們已經跟妳說過這種事情了',
#  '如果你們知道在一起出面前面',
#  '你們不知道該怎麼會在這裡呢',
#  '我們的是不是要跟我們一起去',
#  '而且我知道妳想跟我們一起去',
#  '而且我看到妳這麼做是這種事',
#  '我們要知道妳們家裡的一起吃',
#  '現在妳們父子在一起我會一樣',
#  '不是你們知道我們家裡的一切',
#  '現在是我們的事情都不知道嗎',
#  '哥的是你們不可以去找他們嗎',
#  '如果真的不知道該怎麼做成了',
#  '我們也不是跟妳說好好照顧我',
#  '我也不可以讓他們在這裡等我',
#  '我們要不是一個人在外面的人',
#  '我們不可以讓他們在討論所有',
#  '不是我們要把錢交給我們一點',
#  '我們不可能跟我一起去找方法',
#  '剛才不是說到這個人在這裡鬧',
#  '我們就算了爸爸媽媽在一起吃',
#  '如果有一個人在身邊的人在場',
#  '如果妳知道知道我們在這裡等',
#  '我們這個人是在外人的女朋友',
#  '我們已經跟楊先生說好好照顧',
#  '我們已經跟妳一起去找一起來',
#  '不知道我們是不是要去找她爸',
#  '如果妳不知道該怎麼做成這樣',
#  '不知道該怎麼會在這裡做什麼',
#  '我們可以跟著一起去找方慶堂',
#  '我們已經跟他們一起去開口戶',
#  '我們就是一個人在外面對方家',
#  '如果真的知道我們在這裡等我',
#  '我們不知道該怎麼會在這裡呢',
#  '我們要去找她爸爸爸去吃飯了',
#  '不知道該怎麼會這麼做的事情',
#  '我們的家兒子不會再離開了嗎',
#  '我已經跟你們一起去就是一樣',
#  '我們已經跟楊先生說好好照顧',
#  '你們不要跟我們一起去相親嗎',
#  '我們已經跟楊先生說好幾倍了',
#  '我們去找那些錢跟我們一起吃',
#  '不知道我們家有一個人在一起',
#  '我也不可能跟我們一起去看看',
#  '我們要不是一個人在外面對象',
#  '如果你們不可以讓我們知道嗎',
#  '我們不是要跟他一起去相親嗎',
#  '我們不可能會讓我們的時候了',
#  '如果妳真的想到我們的親朋好',
#  '如果你們不知道我們在一起嗎',
#  '我們不可以當時間公司上班了',
#  '我們家裡不可以去找他們一起',
#  '我看看你們是我們一個人相親',
#  '我們不是不是跟我一個人在家',
#  '這個孩子已經跟你們一起去吧',
#  '不知道該怎麼會這麼做的事情',
#  '我們不可能會讓我們擔心一點',
#  '你們有沒有跟我說話不要亂說',
#  '如果妳真的想到我們家的感情',
#  '不是我們的事情搞得這麼嚴重',
#  '我們不是不是跟我一起去看看',
#  '我們可以跟著他們一起去開口',
#  '是否不是我們跟他一起去一樣',
#  '你們不可以讓我們好好照顧他',
#  '不知道該怎麼會在這裡做什麼',
#  '我們不可以讓你們母女的心情',
#  '你們不可以讓我們一個人同住',
#  '我們要去找她爸爸媽是好是我',
#  '因為你們想當我們的親朋好友',
#  '你怎麼知道我爸爸的是你在忙',
#  '如果妳不知道該怎麼做成這樣',
#  '我已經跟楊先生在一起去找人家',
#  '不用我們要去找昭華借給我們',
#  '否則我就是不知道該怎麼回事',
#  '你怎麼可以跟文隆哥交往出事',
#  '我在這裡的東西都是吃過去了',
#  '我們已經跟楊先生說好幾倍了',
#  '如果妳不知道該怎麼做這麼做',
#  '你們都不知道我爸爸爸媽媽在',
#  '我就不可以讓他們母女好好好',
#  '不是我們要把錢交給你們吃了',
#  '以後不知道該怎麼會這麼做呢',
#  '而且我們不可以讓人家認識她',
#  '我們不是不知道該怎麼回家了',
#  '人家人已經跟妳在一起去開門',
#  '不知道該怎麼會在這裡做什麼',
#  '因為這個是你們的女朋友一樣',
#  '如果我知道妳想跟我在一起嗎',
#  '我看你一定要把錢交出去的事',
#  '我們要去找她爸爸媽媽是一個',
#  '不是我們的事情搞得這麼嚴重',
#  '不然你們要不要跟我們一起去',
#  '如果妳知道知道我在一起出面',
#  '我們已經跟他們一起去開口戶',
#  '不知道該怎麼會在這裡做什麼',
#  '去就可以看到文隆的摩托車上',
#  '我們不是要跟她一起去開口店',
#  '你們要把錢交給我們一點時間',
#  '我們已經跟妳一起去找一起吃',
#  '我們不可以去找他們的時間了',
#  '我們不可以去找他們兩個孩子',
#  '你們不可以去找他們一點時間',
#  '我們不可以當時間公司上班了',
#  '既然你們不可以跟我們一起去',
#  '剛才不是說你們先去找他爸爸',
#  '我們不可以讓他們在外面試試',
#  '我們要去找她爸爸媽媽吃一下',
#  '我們已經跟妳一起去看看醫生',
#  '我們不是一個人在一起出面前',
#  '不知道該怎麼會這麼做的事情',
#  '不是我們的事情都會不會的事',
#  '不是我們不是要去哪裡找我們',
#  '我們不知道該做的是三個小孩',
#  '不要不要跟我們一起去開口嗎',
#  '這間房子已經跟我們一起去了',
#  '我們不可能是我們不是好好的',
#  '我們是否找到一個人在一起嗎',
#  '我們不是不知道我們一起出去',
#  '我們不是一個人在外面的人是',
#  '我看你們去哪裡找人來做什麼',
#  '現在妳們知道了一個人會變成',
#  '不知道該怎麼會在這裡做什麼',
#  '我們應該知道他們在家裡面對',
#  '我們就是一個人在外面的人是',
#  '我們是應該知道妳的手機會了',
#  '我們不可以去找他們的時間嗎',
#  '你們不知道我們一定會好好照',
#  '我們要跟她一起去看看醫生嗎',
#  '現在一個是我的女朋友一起去',
#  '我們已經跟他們一起去開一趟',
#  '我們有一個人同住一屋簷下嗎',
#  '你們不是要跟他一起去開口嗎',
#  '你們都不知道我們一起去外面',
#  '這間公司的是你們的好朋友了',
#  '我們要去找她爸爸媽媽去找她',
#  '這是我們的事情都不知道的嗎',
#  '不知道該怎麼會在這裡做什麼',
#  '否則我們不可以讓他們在擔心',
#  '我們不知道該做的是三個小孩',
#  '這個不是不知道該怎麼回事了',
#  '我們去看看爸爸爸爸會很擔心',
#  '我也不可能會讓我們擔心不好',
#  '我們不知道該怎麼會在這裡鬧',
#  '我們不知道我們家裡了一起吃',
#  '你們不可以讓我們好好照顧家',
#  '如果妳不知道該怎麼做成這樣',
#  '我們去找她爸爸媽媽在一起吃',
#  '而且我看到妳們都不知道該做',
#  '我們不是一個人在一起出面前',
#  '我們有一個人在外面都會不會',
#  '現在你們先去找文進去找他爸',
#  '我們是否不是跟我在一起吃飯',
#  '這是我們的事情搞得這麼嚴重',
#  '我們不知道該怎麼會在這裡呢',
#  '我們要去找昭華看到這種事情',
#  '我們要去找她爸爸媽媽是一個人',
#  '如果說到這麼說我跟妳說話了',
#  '你們有什麼事都可以向我道謝',
#  '我們現在去找人家一起去開口',
#  '我們不可以讓他們在外面試試',
#  '不過你們就是不知道我的孩子',
#  '不用了我們一定會盡力不清楚',
#  '我們是一個人在外面的人相親',
#  '我們去看看看看到這個人是誰',
#  '我們的事情都不知道該怎麼辦',
#  '是董事長夫人現在怎麼回事了',
#  '我們去找她爸爸爸媽是一個人',
#  '我們不是一個人在一起出面前',
#  '如果我們不是你們母女一起去',
#  '我們不是要去找她爸爸的公司',
#  '否則我們不是要去找他們一樣',
#  '我們去看看他是我的公司是你',
#  '現在說什麼我不是你們母女人',
#  '我也不知道該怎麼會在這裡呢',
#  '不用跟我們一定會好好照顧他',
#  '我們已經跟他們一起去開口戶',
#  '不過我們就是不是說這個孩子',
#  '不是我們要把錢交給我們一點',
#  '我們是一個人犯人的人是共犯',
#  '你們不知道我們是有一個律師',
#  '我們不知道我們是有一個律師',
#  '現在就知道妳現在在哪裡找了',
#  '我看看到什麼時候我們的孩子',
#  '我們已經跟楊先生說好幾倍了',
#  '我們不知道該怎麼會在這裡呢',
#  '我們就算了一個人才能夠為止',
#  '如果你們知道我們一起去相親',
#  '你們不可以讓我們好好的照顧',
#  '我們已經跟妳在一起去開門了',
#  '我們要知道妳的手機會被警方',
#  '否則真的不知道該怎麼回來了',
#  '我們要不是一個人在外面上班',
#  '我們不可以去找他們一點時間',
#  '我們不是一個人在外面的地方',
#  ...]

# %%
states_value = encoder_model.predict(test_data_pad[1][np.newaxis,:,:])

# %%
decode_sequence(test_data_pad[10])
# Out:
# '你們有沒有跟我說一些有一些'

# %%
train_caption
# Out:
# ['真 厲 害 \n',
#  '對 了 文 隆 哥 \n',
#  '惜 惜 \n',
#  '沒 有 我 得 不 到 的 \n',
#  '現 在 你 不 誇 獎 我 \n',
#  '你 還 \n',
#  '你 要 把 握 這 個 機 會 \n',
#  '別 在 這 裡 丟 人 現 眼 \n',
#  '當 然 要 知 道 他 的 想 法 \n',
#  '鐵 的 紀 律 的 崇 尚 者 對 吧 \n',
#  '好 不 好 \n',
#  '不 要 牽 扯 我 身 邊 的 人 \n',
#  '眼 睜 睜 看 她 被 你 欺 負 \n',
#  '文 進 你 趕 快 打 電 話 回 去 \n',
#  '我 \n',
#  '不 可 以 \n',
#  '妳 看 現 在 旁 邊 都 沒 有 人 \n',
#  '不 來 沒 關 係 \n',
#  '順 便 把 戶 口 遷 到 監 獄 裡 \n',
#  '有 什 麼 事 明 天 再 說 \n',
#  '好 了 \n',
#  '淑 卿 \n',
#  '現 在 換 我 請 你 \n',
#  '叫 你 不 要 跟 文 琪 來 往 \n',
#  '不 要 說 只 是 稱 讚 幾 句 \n',
#  '再 見 \n',
#  '就 \n',
#  '其 實 換 個 立 場 \n',
#  '真 的 \n',
#  '為 什 麼 去 接 曉 萍 會 這 麼 久 \n',
#  '無 論 妳 有 什 麼 問 題 \n',
#  '阿 勇 請 兩 位 董 事 長 坐 \n',
#  '妳 明 明 就 去 了 \n',
#  '正 源 \n',
#  '我 \n',
#  '被 火 一 燻 眼 淚 就 \n',
#  '不 可 能 \n',
#  '搞 死 自 己 罷 了 \n',
#  '也 沒 有 丟 媽 媽 的 臉 \n',
#  '如 果 不 追 她 \n',
#  '我 交 代 過 文 隆 \n',
#  '媽 妳 先 別 看 \n',
#  '是 美 純 硬 要 留 下 孩 子 \n',
#  '客 人 叫 車 \n',
#  '這 個 點 心 作 得 很 好 \n',
#  '我 要 喝 這 個 \n',
#  '賺 那 一 點 薪 水 \n',
#  '好 嗎 \n',
#  '與 我 無 關 \n',
#  '曉 萍 \n',
#  '你 嚇 到 我 了 \n',
#  '放 進 去 炒 一 炒 \n',
#  '記 住 \n',
#  '但 是 這 個 家 \n',
#  '聽 妳 這 麼 說 \n',
#  '我 真 不 知 道 \n',
#  '你 都 這 麼 說 了 \n',
#  '自 作 自 受 \n',
#  '妳 最 喜 歡 吃 的 \n',
#  '積 極 一 點 找 \n',
#  '來 我 看 帳 單 \n',
#  '嫂 子 妳 看 \n',
#  '需 要 我 教 妳 嗎 \n',
#  '疼 老 婆 \n',
#  '先 過 來 找 我 \n',
#  '是 啊 \n',
#  '妳 是 否 願 意 跟 我 搬 出 去 \n',
#  '妳 也 會 喜 歡 她 的 \n',
#  '所 以 我 這 個 媽 媽 說 話 \n',
#  '現 在 怎 麼 說 警 察 要 來 抓 我 \n',
#  '我 知 道 \n',
#  '我 再 找 時 間 去 了 解 就 好 \n',
#  '不 客 氣 \n',
#  '來 走 該 回 家 了 \n',
#  '什 麼 不 用 \n',
#  '最 好 安 分 點 \n',
#  '他 不 敢 怎 麼 樣 \n',
#  '過 不 了 多 久 \n',
#  '我 \n',
#  '如 果 你 想 追 曉 萍 \n',
#  '有 沒 有 怎 麼 樣 \n',
#  '有 沒 有 遇 到 什 麼 問 題 \n',
#  '我 怕 他 在 裡 面 會 害 怕 \n',
#  '那 你 爸 呢 \n',
#  '用 手 機 定 位 可 以 找 到 劉 先 生 \n',
#  '我 一 定 會 想 辦 法 處 理 的 \n',
#  '我 去 處 理 \n',
#  '他 們 倆 怎 麼 走 了 \n',
#  '人 嚇 人 會 嚇 死 人 的 \n',
#  '撞 壞 你 賠 不 起 \n',
#  '沒 人 不 是 更 好 嗎 \n',
#  '拿 不 出 三 十 萬 保 釋 金 \n',
#  '妳 是 不 是 怕 叔 叔 出 來 \n',
#  '你 的 面 子 \n',
#  '乾 脆 趁 今 天 這 個 機 會 \n',
#  '不 會 有 事 的 \n',
#  '現 在 馬 上 出 去 \n',
#  '但 是 人 家 不 這 麼 想 \n',
#  '白 佳 佳 態 度 一 直 很 強 硬 \n',
#  '直 接 闖 進 來 \n',
#  '謝 謝 你 旺 哥 \n',
#  '冠 軍 是 世 上 \n',
#  '做 自 己 \n',
#  '別 這 樣 \n',
#  '最 後 仍 是 如 此 收 場 \n',
#  '我 要 告 訴 你 們 的 是 \n',
#  '我 先 把 手 錶 給 妳 們 \n',
#  '絕 不 會 輸 給 她 \n',
#  '沒 事 吧 \n',
#  '你 為 什 麼 要 追 人 \n',
#  '阿 嬤 不 行 \n',
#  '一 定 是 仗 著 姊 夫 對 她 的 照 顧 \n',
#  '都 是 有 頭 有 臉 \n',
#  '喂 阿 爸 的 灶 腳 你 好 \n',
#  '好 \n',
#  '怎 麼 會 這 樣 \n',
#  '如 果 有 空 會 回 去 看 我 媽 媽 \n',
#  '妳 不 是 有 話 告 訴 我 嗎 \n',
#  '無 論 如 何 韋 恩 \n',
#  '我 當 然 了 解 \n',
#  '剛 才 騎 摩 托 車 跑 掉 的 \n',
#  '你 在 掩 飾 什 麼 \n',
#  '有 你 的 幫 忙 \n',
#  '沒 關 係 \n',
#  '撐 得 住 嗎 \n',
#  '妳 去 休 息 吧 \n',
#  '很 看 重 我 的 能 力 \n',
#  '其 實 我 說 的 不 是 妳 親 阿 姨 \n',
#  '臉 上 皺 紋 就 多 了 好 幾 條 \n',
#  '不 過 是 一 個 坐 檯 小 姐 \n',
#  '才 會 這 麼 說 的 對 吧 \n',
#  '文 琪 這 麼 凶 \n',
#  '這 女 人 的 事 \n',
#  '還 是 要 走 法 律 程 序 \n',
#  '播 放 吧 \n',
#  '好 我 什 麼 都 不 做 \n',
#  '喂 你 \n',
#  '爸 還 在 生 我 的 氣 \n',
#  '我 是 她 老 公 耶 \n',
#  '站 都 站 不 穩 了 \n',
#  '對 他 一 點 威 脅 都 沒 有 \n',
#  '我 會 唱 我 唱 給 妳 聽 \n',
#  '知 道 嗎 \n',
#  '就 是 啊 \n',
#  '像 你 心 機 這 麼 重 的 人 \n',
#  '不 要 像 我 爸 一 樣 \n',
#  '隨 便 你 們 \n',
#  '我 絕 不 會 後 悔 \n',
#  '不 對 \n',
#  '不 是 \n',
#  '沒 關 係 \n',
#  '可 是 \n',
#  '我 剛 才 怕 過 號 \n',
#  '時 代 變 了 \n',
#  '來 \n',
#  '我 怎 麼 面 對 外 人 的 眼 光 \n',
#  '放 開 我 \n',
#  '對 哦 你 說 得 很 有 道 理 \n',
#  '文 隆 大 師 講 道 \n',
#  '高 先 生 \n',
#  '我 向 妳 保 證 \n',
#  '不 喜 歡 我 \n',
#  '現 在 文 琪 比 我 重 要 \n',
#  '好 \n',
#  '就 好 笑 了 \n',
#  '只 有 妳 一 個 人 \n',
#  '焢 肉 這 樣 對 嗎 \n',
#  '現 在 我 們 配 合 他 的 要 求 \n',
#  '我 也 有 責 任 \n',
#  '別 再 說 了 \n',
#  '擔 心 什 麼 \n',
#  '俊 傑 有 所 改 變 很 好 \n',
#  '三 千 嗎 \n',
#  '是 文 進 不 小 心 跌 倒 \n',
#  '搖 滾 \n',
#  '惡 臉 相 向 \n',
#  '熱 習 慣 了 \n',
#  '再 說 \n',
#  '但 這 個 人 \n',
#  '動 不 動 就 離 婚 \n',
#  '媽 我 洗 好 了 \n',
#  '冤 枉 啊 \n',
#  '伯 父 說 你 們 去 吃 飯 \n',
#  '但 是 此 時 此 刻 \n',
#  '她 本 來 就 是 這 樣 \n',
#  '他 有 沒 有 跟 妳 說 什 麼 \n',
#  '小 鮮 肉 \n',
#  '你 一 定 要 相 信 我 的 投 資 眼 光 \n',
#  '好 了 \n',
#  '你 要 想 清 楚 \n',
#  '四 個 臭 皮 匠 \n',
#  '我 會 一 肩 扛 下 \n',
#  '叔 叔 抱 歉 \n',
#  '回 去 吧 \n',
#  '我 要 去 找 冠 軍 \n',
#  '好 啦 \n',
#  '他 是 我 過 去 玩 樂 團 的 好 朋 友 \n',
#  '快 啊 \n',
#  '還 怪 我 \n',
#  '人 不 舒 服 嗎 \n',
#  '媽 吃 飯 \n',
#  '我 讓 她 來 上 班 \n',
#  '直 接 求 婚 吧 \n',
#  '陪 妳 練 拳 嗎 \n',
#  '等 他 們 結 了 婚 \n',
#  '警 察 來 家 裡 說 什 麼 \n',
#  '肚 子 痛 \n',
#  '大 還 小 \n',
#  '最 主 要 是 \n',
#  '現 在 住 豪 宅 開 跑 車 \n',
#  '看 見 妳 找 到 幸 福 \n',
#  '妳 不 要 生 氣 \n',
#  '爸 \n',
#  '嘉 誠 別 聽 她 的 \n',
#  '遇 到 張 美 純 她 媽 媽 \n',
#  '沒 錯 \n',
#  '彷 彿 給 他 們 一 口 飯 吃 \n',
#  '多 少 學 了 一 點 技 巧 \n',
#  '這 是 一 定 的 啊 \n',
#  '煮 好 稀 飯 了 \n',
#  '加 \n',
#  '剛 才 爸 不 是 說 了 嗎 \n',
#  '對 了 伯 母 \n',
#  '不 要 鬧 哦 \n',
#  '對 \n',
#  '都 沒 有 留 下 痕 跡 \n',
#  '他 已 經 懷 恨 在 心 了 \n',
#  '法 官 都 是 高 高 在 上 \n',
#  '為 什 麼 她 媽 媽 \n',
#  '但 是 她 上 班 \n',
#  '剛 才 幫 她 把 脈 \n',
#  '好 \n',
#  '你 跟 淑 卿 已 經 離 婚 了 \n',
#  '妳 都 得 罪 光 了 \n',
#  '好 了 別 再 念 了 \n',
#  '我 告 訴 妳 \n',
#  '沒 有 這 個 道 理 \n',
#  '但 是 妳 也 不 可 以 說 得 這 麼 難 聽 \n',
#  '幸 好 \n',
#  '爸 我 有 一 個 好 辦 法 \n',
#  '沒 大 沒 小 \n',
#  '抱 歉 高 太 太 \n',
#  '都 一 把 年 紀 了 \n',
#  '最 好 離 她 遠 一 點 \n',
#  '我 忘 了 \n',
#  '你 還 是 快 去 收 拾 行 李 \n',
#  '老 公 \n',
#  '感 謝 \n',
#  '但 是 伯 父 \n',
#  '他 說 不 計 較 \n',
#  '痛 什 麼 \n',
#  '我 一 個 個 開 除 你 們 \n',
#  '好 \n',
#  '聽 見 沒 有 \n',
#  '我 告 訴 你 \n',
#  '那 那 我 \n',
#  '之 前 我 的 確 說 過 \n',
#  '菩 薩 在 上 \n',
#  '就 是 矮 人 一 截 \n',
#  '當 然 不 會 \n',
#  '逼 我 把 錢 交 出 來 \n',
#  '說 那 些 \n',
#  '感 謝 \n',
#  '原 本 這 個 家 所 有 的 東 西 \n',
#  '媽 \n',
#  '如 果 我 們 不 讓 步 \n',
#  '炸 的 啦 \n',
#  '大 家 拜 拜 \n',
#  '高 律 師 都 說 了 \n',
#  '三 餐 過 得 去 \n',
#  '剛 才 無 論 我 怎 麼 阻 止 \n',
#  '難 道 你 又 想 毀 掉 嗎 \n',
#  '不 是 鵲 巢 鳩 占 嗎 \n',
#  '為 了 曉 萍 嗎 \n',
#  '她 也 是 為 了 你 們 好 \n',
#  '好 啊 \n',
#  '所 以 一 回 台 灣 \n',
#  '我 一 定 道 謝 \n',
#  '媽 真 的 很 過 分 \n',
#  '如 果 你 敢 把 他 的 臉 拍 黑 掉 \n',
#  '妳 掉 下 去 之 後 無 法 呼 吸 \n',
#  '也 不 想 想 兩 個 人 加 起 來 \n',
#  '又 沒 回 來 叫 什 麼 \n',
#  '還 繼 續 折 磨 我 \n',
#  '來 \n',
#  '但 我 做 不 到 \n',
#  '硬 要 混 黑 道 \n',
#  '走 \n',
#  '一 千 二 \n',
#  '我 抗 議 \n',
#  '是 文 隆 的 堂 妹 \n',
#  '我 當 然 知 道 是 玫 瑰 花 \n',
#  '住 口 \n',
#  '好 了 \n',
#  '還 是 懷 疑 文 隆 是 嫌 疑 犯 嗎 \n',
#  '阿 嬤 爸 媽 \n',
#  '慧 君 的 肚 子 等 不 了 了 \n',
#  '是 啊 \n',
#  '因 為 停 在 路 邊 才 會 被 偷 走 \n',
#  '文 揚 口 才 那 麼 好 \n',
#  '妳 怎 麼 會 送 我 媽 來 醫 院 \n',
#  '我 不 只 愛 妳 \n',
#  '收 什 麼 隊 兩 個 人 而 已 \n',
#  '究 竟 怎 麼 了 嘉 誠 \n',
#  '要 不 要 緊 \n',
#  '昭 華 什 麼 事 \n',
#  '一 直 擺 臉 色 給 我 看 \n',
#  '既 然 要 演 戲 \n',
#  '其 實 我 會 這 麼 拚 \n',
#  '進 來 \n',
#  '沒 有 你 好 煩 \n',
#  '提 到 我 兒 子 幹 嘛 \n',
#  '這 裡 也 有 \n',
#  '劉 董 抱 歉 \n',
#  '我 \n',
#  '安 靜 \n',
#  '遲 到 會 不 好 意 思 \n',
#  '好 了 \n',
#  '文 隆 很 有 志 氣 \n',
#  '是 啊 \n',
#  '包 在 我 身 上 \n',
#  '是 這 樣 的 \n',
#  '覺 得 自 己 是 一 個 \n',
#  '不 教 訓 你 \n',
#  '而 且 我 回 去 上 班 \n',
#  '晚 上 睡 不 著 \n',
#  '拜 託 \n',
#  '有 一 個 歐 吉 桑 出 車 禍 \n',
#  '幫 我 上 去 看 看 \n',
#  '為 我 賣 命 衝 業 績 呢 \n',
#  '她 都 是 依 約 行 事 \n',
#  '雖 然 脾 氣 有 點 差 \n',
#  '我 先 去 瞇 一 會 兒 好 了 \n',
#  '問 題 才 正 要 開 始 \n',
#  '有 有 道 理 \n',
#  '應 該 別 無 他 意 \n',
#  '我 都 願 意 接 受 \n',
#  '媽 我 看 \n',
#  '我 不 去 \n',
#  '奇 怪 \n',
#  '不 \n',
#  '阿 嬤 \n',
#  '對 啊 她 是 我 女 朋 友 \n',
#  '好 \n',
#  '衣 服 溼 了 又 何 妨 \n',
#  '無 論 如 何 \n',
#  '我 對 自 己 越 來 越 沒 有 信 心 \n',
#  '伯 母 妳 不 要 難 過 \n',
#  '爸 \n',
#  '來 \n',
#  '如 果 妳 不 想 去 告 訴 我 \n',
#  '我 們 再 等 等 吧 \n',
#  '不 是 檢 察 官 \n',
#  '會 受 不 了 耶 \n',
#  '眼 裡 只 有 美 女 \n',
#  '你 住 海 邊 哦 \n',
#  '都 怪 你 們 男 人 \n',
#  '小 心 \n',
#  '可 惡 的 人 \n',
#  '謝 謝 \n',
#  '過 去 拍 賣 都 寫 單 子 \n',
#  '今 天 菜 色 不 錯 耶 \n',
#  '不 可 能 \n',
#  '好 了 走 \n',
#  '我 有 啊 \n',
#  '看 到 我 被 抓 去 關 \n',
#  '坐 下 \n',
#  '千 萬 不 要 找 \n',
#  '我 告 訴 她 這 份 工 作 \n',
#  '都 經 過 她 的 同 意 \n',
#  '文 揚 就 是 劉 先 生 的 半 子 了 \n',
#  '糟 了 \n',
#  '我 看 \n',
#  '我 已 經 很 不 開 心 了 \n',
#  '文 \n',
#  '還 有 人 追 妳 \n',
#  '為 什 麼 男 人 都 這 麼 自 私 \n',
#  '文 揚 \n',
#  '曉 萍 \n',
#  '我 知 道 我 的 努 力 還 不 夠 \n',
#  '文 隆 \n',
#  '妳 好 \n',
#  '如 同 你 告 訴 阿 嬤 的 \n',
#  '幸 好 哥 良 心 發 現 \n',
#  '幫 忙 出 頭 \n',
#  '所 以 我 只 好 \n',
#  '所 以 妳 的 意 思 是 \n',
#  '阿 嬤 再 見 \n',
#  '進 來 \n',
#  '叔 叔 說 到 這 個 我 很 不 好 意 思 \n',
#  '叔 叔 拜 託 你 \n',
#  '沒 有 這 是 暫 時 的 \n',
#  '如 果 妳 再 逼 我 \n',
#  '沒 事 \n',
#  '你 應 該 可 以 包 容 吧 \n',
#  '好 \n',
#  '他 們 還 算 不 錯 \n',
#  '跟 爸 爸 拜 拜 \n',
#  '美 女 \n',
#  '我 們 逮 捕 你 \n',
#  '黃 正 源 呢 \n',
#  '我 是 覺 得 這 個 很 醜 \n',
#  '拜 拜 \n',
#  '一 屋 二 妻 的 生 活 \n',
#  '頭 部 很 重 要 \n',
#  '拜 託 妳 別 來 鬧 \n',
#  '來 \n',
#  '坐 那 邊 \n',
#  '對 了 董 事 長 \n',
#  '如 果 沒 有 經 過 我 同 意 就 公 開 \n',
#  '最 會 撒 撟 了 \n',
#  '我 還 要 顧 一 鍋 湯 \n',
#  '爸 我 們 走 \n',
#  '哪 有 緊 張 \n',
#  '謝 謝 \n',
#  '小 心 哦 \n',
#  '我 今 天 去 市 場 買 菜 \n',
#  '現 在 只 有 這 條 路 \n',
#  '現 在 以 為 這 間 房 子 是 你 們 的 \n',
#  '昭 華 \n',
#  '怎 麼 腫 成 這 樣 \n',
#  '十 萬 塊 \n',
#  '剛 才 去 看 伯 父 \n',
#  '為 什 麼 一 定 要 照 妳 的 安 排 走 \n',
#  '都 跟 妳 分 享 \n',
#  '沒 發 燒 啊 \n',
#  '文 琪 妳 好 \n',
#  '聽 到 什 麼 \n',
#  '我 要 減 肥 \n',
#  '騎 車 小 心 \n',
#  '不 不 太 一 樣 \n',
#  '究 竟 該 怎 麼 做 \n',
#  '聽 見 沒 有 \n',
#  '玉 婷 \n',
#  '我 也 不 知 道 \n',
#  '你 不 是 跟 我 一 起 出 去 嗎 \n',
#  '好 了 快 去 洗 澡 \n',
#  '妳 打 個 夠 \n',
#  '歡 迎 請 坐 \n',
#  '媽 媽 已 經 被 白 佳 佳 那 個 狐 狸 精 \n',
#  '真 的 捨 不 得 \n',
#  '你 認 為 法 官 \n',
#  '既 然 搬 進 來 了 \n',
#  '快 去 \n',
#  '也 很 想 我 對 吧 \n',
#  '有 些 讓 你 害 怕 的 事 \n',
#  '一 定 會 的 \n',
#  '這 \n',
#  '帶 曉 萍 去 做 街 頭 表 演 \n',
#  '警 民 關 係 要 維 護 \n',
#  '拿 出 來 看 看 \n',
#  '乖 \n',
#  '來 孩 子 抱 著 \n',
#  '一 堆 信 還 沒 送 呢 \n',
#  '想 自 己 先 籌 錢 \n',
#  '他 為 什 麼 不 可 以 去 \n',
#  '對 \n',
#  '哥 \n',
#  '玉 婷 \n',
#  '你 從 不 覺 得 自 己 做 錯 \n',
#  '謝 謝 伯 父 \n',
#  '我 能 夠 了 解 \n',
#  '我 去 看 看 \n',
#  '好 了 \n',
#  '但 是 準 備 婚 禮 很 累 \n',
#  '冠 軍 \n',
#  '謝 謝 你 \n',
#  '沒 事 \n',
#  '我 不 是 不 容 忍 \n',
#  '來 \n',
#  '怎 麼 還 有 其 他 人 \n',
#  '我 們 應 該 同 甘 共 苦 \n',
#  '也 許 她 會 提 早 告 訴 我 們 \n',
#  '讓 雙 方 都 能 夠 接 受 \n',
#  '他 會 假 裝 肚 子 痛 \n',
#  '知 不 知 道 還 有 誰 在 販 賣 \n',
#  '關 心 可 以 \n',
#  '不 會 \n',
#  '不 想 跟 她 有 交 集 \n',
#  '就 是 啊 \n',
#  '阿 嬤 買 的 精 力 湯 \n',
#  '怎 麼 可 能 不 著 急 \n',
#  '妳 先 開 口 哦 \n',
#  '老 師 來 的 時 候 \n',
#  '收 了 也 好 \n',
#  '那 裡 我 知 道 \n',
#  '其 實 劉 易 宏 是 一 個 \n',
#  '順 便 吃 消 夜 \n',
#  '對 啊 \n',
#  '走 \n',
#  '不 知 道 怎 麼 回 事 \n',
#  '妳 要 高 興 才 對 \n',
#  '龜 毛 什 麼 啊 \n',
#  '破 了 就 丟 掉 \n',
#  '又 要 出 什 麼 事 了 \n',
#  '不 是 人 當 然 也 可 以 看 \n',
#  '還 有 進 步 的 空 間 \n',
#  '妳 知 道 嗎 到 今 天 為 止 \n',
#  '曉 萍 這 女 孩 很 乖 \n',
#  '不 是 我 要 謝 謝 妳 \n',
#  '表 演 就 是 這 樣 啊 \n',
#  '我 去 外 面 聽 \n',
#  '幫 幫 忙 \n',
#  '李 三 郎 做 這 麼 多 壞 事 \n',
#  '好 我 知 道 了 \n',
#  '人 也 很 憨 厚 老 實 \n',
#  '記 得 妳 告 訴 過 我 \n',
#  '方 曉 萍 \n',
#  '對 哦 \n',
#  '你 是 不 是 認 為 \n',
#  '對 了 高 先 生 \n',
#  '前 陣 子 比 較 忙 \n',
#  '不 要 留 下 後 患 知 道 嗎 \n',
#  '抱 歉 \n',
#  '忘 了 嗎 \n',
#  '依 照 董 事 長 的 意 思 處 理 \n',
#  '安 排 最 好 的 醫 生 \n',
#  '是 啊 \n',
#  '你 皮 繃 緊 一 點 \n',
#  '怎 麼 樣 \n',
#  '但 是 到 現 在 都 沒 看 到 人 \n',
#  '拜 託 你 \n',
#  '你 媽 是 捨 不 得 你 們 \n',
#  '爸 爸 太 失 敗 了 \n',
#  '好 沒 問 題 \n',
#  '沒 有 \n',
#  '我 很 久 沒 找 妳 爸 爸 聊 天 了 \n',
#  '不 會 冠 軍 \n',
#  '什 麼 辦 法 阿 嬤 \n',
#  '沒 有 我 現 在 意 思 是 \n',
#  '我 還 是 另 找 他 人 吧 \n',
#  '去 看 看 有 什 麼 飲 料 和 點 心 \n',
#  '什 麼 事 \n',
#  '絕 對 不 可 以 \n',
#  '伯 父 確 實 會 看 人 \n',
#  '這 樣 啊 \n',
#  '伯 父 要 你 們 告 訴 我 \n',
#  '真 是 氣 壞 了 \n',
#  '就 叫 玉 婷 不 要 進 來 \n',
#  '妳 憑 什 麼 打 我 \n',
#  '我 們 要 用 另 一 個 角 度 看 \n',
#  '不 小 心 中 彈 受 傷 \n',
#  '不 行 我 看 \n',
#  '就 是 開 旅 行 社 的 \n',
#  '你 還 在 生 氣 嗎 \n',
#  '我 相 信 文 隆 \n',
#  '慢 著 \n',
#  '還 是 阿 嬤 帶 了 餅 乾 \n',
#  '是 啊 \n',
#  '你 看 \n',
#  '妳 幫 幫 忙 \n',
#  '是 因 為 \n',
#  '我 知 道 \n',
#  '很 久 沒 看 到 妳 \n',
#  '玉 婷 \n',
#  '玉 婷 \n',
#  '給 我 一 個 重 新 開 始 的 機 會 \n',
#  '對 啊 \n',
#  '一 個 聰 明 的 孩 子 \n',
#  '阿 勝 的 共 犯 \n',
#  '當 時 我 告 訴 過 妳 \n',
#  '抱 好 \n',
#  '公 司 和 妳 個 人 的 理 財 報 告 \n',
#  '有 男 朋 友 了 \n',
#  '不 對 一 點 都 不 剛 好 \n',
#  '外 觀 看 來 都 差 不 多 \n',
#  '沒 有 啦 大 嫂 \n',
#  '謝 謝 \n',
#  '好 了 \n',
#  '一 進 門 一 句 話 都 還 沒 說 \n',
#  '我 不 要 牠 好 凶 \n',
#  '逛 街 啊 \n',
#  '再 說 明 坤 是 我 的 親 弟 弟 \n',
#  '擔 心 \n',
#  '如 果 讓 董 事 長 夫 人 去 找 白 佳 佳 \n',
#  '來 \n',
#  '祝 你 生 日 快 樂 哦 \n',
#  '他 說 要 離 開 我 \n',
#  '等 等 \n',
#  '妳 有 沒 有 說 錯 \n',
#  '還 悶 不 吭 聲 \n',
#  '好 快 \n',
#  '跟 妳 說 話 \n',
#  '現 在 又 睡 著 了 \n',
#  '少 囉 嗦 \n',
#  '妳 的 摩 托 車 不 見 與 我 何 干 \n',
#  '不 過 我 的 確 認 為 \n',
#  '蔡 一 明 才 是 殺 人 犯 \n',
#  '拜 託 快 點 \n',
#  '相 信 這 樣 對 雙 方 \n',
#  '他 是 男 孩 子 \n',
#  '很 漂 亮 哦 \n',
#  '對 \n',
#  '可 以 跟 到 這 麼 好 的 老 闆 \n',
#  '怎 麼 這 麼 巧 \n',
#  '媽 \n',
#  '好 \n',
#  '沒 有 人 願 意 聽 他 說 話 \n',
#  '很 登 對 \n',
#  '我 有 事 情 要 跟 妳 商 量 \n',
#  '會 有 什 麼 反 應 \n',
#  '我 為 了 什 麼 \n',
#  '會 不 會 身 上 沒 錢 了 \n',
#  '誰 知 道 逛 一 逛 \n',
#  '來 \n',
#  '現 在 看 到 什 麼 \n',
#  '嬸 嬸 不 用 客 氣 \n',
#  '阿 強 說 那 什 麼 話 啊 \n',
#  '好 像 很 對 不 起 自 己 \n',
#  '阿 嬤 抱 歉 \n',
#  '現 在 在 西 餐 廳 唱 歌 \n',
#  '他 們 住 哪 裡 \n',
#  '何 時 要 出 團 \n',
#  '再 見 \n',
#  '一 直 叫 不 醒 \n',
#  '伯 母 \n',
#  '一 定 是 我 們 的 光 榮 \n',
#  '一 定 要 \n',
#  '包 括 感 情 都 一 樣 \n',
#  '如 果 你 再 胡 說 八 道 \n',
#  '絕 對 沒 問 題 \n',
#  '對 快 我 們 還 要 選 歌 呢 \n',
#  '白 天 讓 孩 子 睡 到 飽 \n',
#  '剛 才 突 然 頭 暈 \n',
#  '妳 上 班 還 要 照 顧 冠 軍 \n',
#  '去 啦 \n',
#  '我 好 像 在 哪 裡 見 過 你 \n',
#  '佳 佳 說 得 對 \n',
#  '文 揚 \n',
#  '所 以 這 幾 天 出 門 前 \n',
#  '來 快 \n',
#  '而 且 沒 想 到 \n',
#  '高 家 就 要 負 責 到 底 \n',
#  '看 到 \n',
#  '平 安 就 是 福 \n',
#  '會 不 會 管 太 多 了 \n',
#  '不 會 \n',
#  '他 一 定 會 回 頭 的 \n',
#  '還 有 \n',
#  '冠 軍 也 不 會 跟 著 我 們 吃 苦 \n',
#  '痛 \n',
#  '我 知 道 了 \n',
#  '我 相 信 她 絕 對 永 遠 看 不 出 \n',
#  '什 麼 事 呢 \n',
#  '所 以 我 打 算 \n',
#  '對 不 起 \n',
#  '有 時 我 真 的 覺 得 \n',
#  '慧 君 呢 \n',
#  '先 去 找 人 來 救 我 \n',
#  '專 程 送 蛋 糕 來 \n',
#  '沒 有 他 是 跟 妳 撒 嬌 \n',
#  '我 看 還 是 你 幫 我 解 籤 詩 吧 \n',
#  '生 產 線 少 了 一 個 人 \n',
#  '如 果 爸 媽 知 道 \n',
#  '文 揚 你 怎 麼 這 麼 說 \n',
#  '好 \n',
#  '做 個 徹 底 檢 查 \n',
#  '確 實 是 從 度 假 村 運 過 來 的 \n',
#  '謝 謝 \n',
#  '我 們 立 場 不 同 \n',
#  '如 果 老 闆 不 開 心 \n',
#  '對 啊 妳 有 天 線 \n',
#  '又 無 法 逮 捕 他 \n',
#  '我 們 談 妥 事 情 \n',
#  '許 小 姐 不 是 離 婚 了 嗎 \n',
#  '對 社 會 毫 無 貢 獻 \n',
#  '妳 看 \n',
#  '我 \n',
#  '連 一 個 \n',
#  '真 靈 驗 \n',
#  '好 了 \n',
#  '很 反 對 你 跟 曉 萍 在 一 起 \n',
#  '你 一 定 要 救 我 兒 子 \n',
#  '我 親 眼 所 見 \n',
#  '如 果 事 情 曝 光 \n',
#  '但 是 卻 一 直 追 不 到 的 女 孩 \n',
#  '是 啊 董 事 長 夫 人 \n',
#  '像 我 藏 不 住 話 \n',
#  '告 訴 你 再 過 不 久 \n',
#  '如 果 遇 上 之 後 \n',
#  '雖 然 沒 有 你 媽 媽 作 的 好 吃 \n',
#  '我 麻 煩 妳 帶 來 的 東 西 \n',
#  '但 是 我 現 在 真 的 沒 有 勇 氣 \n',
#  '走 \n',
#  '文 隆 \n',
#  '好 \n',
#  '實 際 上 沒 有 感 情 了 \n',
#  '順 便 去 擦 藥 \n',
#  '好 點 了 \n',
#  '拜 拜 \n',
#  '越 快 越 好 啊 \n',
#  '別 再 鬥 嘴 了 \n',
#  '不 喜 歡 吃 餐 廳 \n',
#  '有 沒 有 怎 麼 樣 \n',
#  '擔 心 這 些 有 的 沒 的 \n',
#  '現 在 能 否 \n',
#  '戲 弄 別 人 的 感 情 \n',
#  '現 在 想 想 \n',
#  '不 客 氣 \n',
#  '他 才 會 惱 羞 成 怒 \n',
#  '有 任 何 需 要 注 意 的 地 方 \n',
#  '慧 君 \n',
#  '麻 煩 你 了 \n',
#  '台 灣 不 只 我 一 個 律 師 \n',
#  '妳 今 天 來 晚 了 \n',
#  '爸 媽 會 計 較 這 些 嗎 \n',
#  '你 看 好 嗎 \n',
#  '如 果 辦 超 渡 法 會 \n',
#  '我 教 訓 他 \n',
#  '護 士 小 姐 不 好 意 思 \n',
#  '姊 夫 先 告 訴 你 \n',
#  '搞 清 楚 \n',
#  '好 別 鬧 了 \n',
#  '天 氣 這 麼 熱 \n',
#  '真 的 嗎 \n',
#  '拜 拜 \n',
#  '讓 警 察 去 追 就 好 \n',
#  '妳 好 意 思 嗎 \n',
#  '不 准 我 們 跟 他 見 面 \n',
#  '妳 不 要 生 氣 \n',
#  '所 以 若 真 要 這 麼 做 \n',
#  '別 影 響 別 人 \n',
#  '真 的 很 謝 謝 你 們 \n',
#  '如 果 你 們 沒 有 其 他 問 題 \n',
#  '有 位 富 商 叫 劉 易 宏 \n',
#  '對 我 眉 開 眼 笑 是 應 該 的 \n',
#  '回 到 家 都 幾 點 了 \n',
#  '請 妳 放 心 \n',
#  '幸 好 我 對 妳 有 信 心 \n',
#  '我 們 夫 妻 能 否 來 幫 忙 \n',
#  '妳 在 這 裡 坐 一 會 兒 \n',
#  '才 幾 天 而 已 \n',
#  '不 知 道 \n',
#  '沒 時 間 洗 衣 服 \n',
#  '突 然 嚇 一 跳 \n',
#  '是 一 個 郵 差 \n',
#  '我 覺 得 很 浪 費 \n',
#  '覺 得 很 感 動 \n',
#  '明 天 才 會 回 來 \n',
#  '結 果 現 在 讓 她 出 事 了 \n',
#  '你 應 該 放 手 讓 她 自 己 試 試 \n',
#  '我 覺 得 這 件 事 很 離 譜 \n',
#  '你 就 慢 慢 等 \n',
#  '文 揚 約 我 在 這 裡 見 面 \n',
#  '叫 他 跑 跑 看 \n',
#  '才 會 害 死 我 的 孩 子 \n',
#  '現 在 已 經 安 全 沒 事 了 \n',
#  '讓 我 工 作 \n',
#  '你 們 最 好 要 有 心 理 準 備 \n',
#  '她 怎 麼 來 了 \n',
#  '妳 \n',
#  '沙 發 \n',
#  '他 們 一 定 很 高 興 \n',
#  '對 \n',
#  '不 意 外 \n',
#  '怎 麼 是 你 啊 \n',
#  '玉 婷 不 好 意 思 \n',
#  '快 影 響 心 臟 了 \n',
#  '一 點 都 不 覺 得 麻 煩 \n',
#  '儘 管 來 找 我 無 妨 \n',
#  '好 了 別 叫 我 董 事 長 \n',
#  '媽 \n',
#  '好 \n',
#  '之 前 文 隆 交 保 一 事 \n',
#  '不 過 很 有 錢 \n',
#  '你 知 道 嗎 外 人 都 \n',
#  '妳 \n',
#  '阿 嬤 回 去 了 \n',
#  '這 些 畫 面 只 能 證 明 \n',
#  '接 下 來 有 沒 有 什 麼 打 算 \n',
#  '好 吧 \n',
#  '你 不 用 跑 車 \n',
#  '不 好 意 思 什 麼 \n',
#  '怎 麼 會 這 樣 呢 \n',
#  '我 不 是 牽 扯 \n',
#  '不 害 臊 嗎 \n',
#  '來 \n',
#  '知 道 因 為 我 的 關 係 \n',
#  '媽 \n',
#  '開 開 心 心 來 喝 喜 酒 \n',
#  '任 何 人 傷 害 妳 \n',
#  '讓 他 們 兄 弟 和 好 才 對 \n',
#  '我 沒 時 間 跟 你 瞎 扯 \n',
#  '我 們 想 找 一 些 線 索 \n',
#  '對 不 起 \n',
#  '再 見 \n',
#  '現 在 攻 堅 \n',
#  '我 小 的 時 候 生 病 \n',
#  '小 心 \n',
#  '躺 好 哦 \n',
#  '請 你 小 聲 說 話 \n',
#  '你 的 舉 手 之 勞 \n',
#  '不 好 意 思 \n',
#  '好 了 \n',
#  '一 共 三 千 \n',
#  '是 啊 \n',
#  '是 啊 白 小 姐 \n',
#  '都 是 很 久 以 前 的 事 了 \n',
#  '倒 車 \n',
#  '哥 \n',
#  '誰 知 道 在 那 裡 \n',
#  '伯 父 謝 謝 \n',
#  '準 備 辦 桌 的 東 西 \n',
#  '怎 麼 了 \n',
#  '是 啊 \n',
#  '我 做 出 傷 害 你 的 事 \n',
#  '為 什 麼 不 提 早 告 訴 我 \n',
#  '誰 說 妳 只 剩 一 隻 手 \n',
#  '一 天 就 好 我 帶 他 出 去 玩 \n',
#  '我 們 有 錢 \n',
#  '你 才 後 繼 無 力 \n',
#  '來 坐 \n',
#  '趁 熱 喝 哦 \n',
#  '這 樣 心 情 就 會 好 了 \n',
#  '如 果 你 們 願 意 常 回 來 吃 \n',
#  '尤 其 知 道 加 害 者 \n',
#  '不 被 騙 怎 麼 會 成 長 呢 \n',
#  '是 啊 \n',
#  '既 然 如 此 \n',
#  '因 為 我 要 訂 一 台 \n',
#  '很 好 \n',
#  '咖 啡 有 千 百 種 \n',
#  '不 要 胡 說 \n',
#  '文 隆 來 \n',
#  '我 一 打 開 \n',
#  '你 生 病 了 \n',
#  '我 煮 給 妳 吃 \n',
#  '我 不 僅 要 整 包 拿 走 \n',
#  '昨 天 來 家 裡 幫 忙 打 掃 \n',
#  '妳 的 東 西 忘 了 拿 \n',
#  '你 又 不 是 不 知 道 我 的 個 性 \n',
#  '有 祕 密 嗎 \n',
#  '妳 們 不 要 再 吵 了 好 嗎 \n',
#  '爸 媽 我 跟 你 們 一 起 去 \n',
#  '直 到 早 上 才 睡 著 \n',
#  '是 誰 拿 了 那 筆 錢 的 話 \n',
#  '如 果 照 做 \n',
#  '花 生 粉 少 一 點 \n',
#  '否 則 會 耽 誤 行 程 \n',
#  '是 賴 經 理 \n',
#  '這 樣 \n',
#  '難 怪 叔 叔 疼 你 \n',
#  '什 麼 馬 後 炮 \n',
#  '三 百 萬 真 的 不 算 什 麼 \n',
#  '想 那 些 \n',
#  '來 曉 萍 來 \n',
#  '女 孩 子 秀 氣 一 點 \n',
#  '你 不 想 讓 我 花 錢 \n',
#  '你 都 已 經 開 口 了 \n',
#  '只 要 我 們 好 好 保 持 \n',
#  '我 沒 有 騙 你 \n',
#  '來 \n',
#  '我 幫 妳 拿 過 去 \n',
#  '巷 尾 阿 明 的 表 妹 \n',
#  '冠 軍 \n',
#  '我 真 高 興 \n',
#  '一 般 會 這 麼 說 \n',
#  '他 \n',
#  '一 定 會 好 好 照 顧 冠 軍 \n',
#  '妳 想 做 什 麼 \n',
#  '媽 媽 最 氣 人 家 說 我 閒 話 \n',
#  '明 明 跟 我 約 好 了 \n',
#  '這 位 太 太 不 好 意 思 \n',
#  '什 麼 時 候 來 的 \n',
#  '咖 啡 還 沒 喝 完 耶 \n',
#  '所 有 事 都 是 我 一 個 人 做 的 \n',
#  '那 我 呢 \n',
#  '伯 父 你 不 要 胡 思 亂 想 \n',
#  '大 哥 \n',
#  '他 們 永 遠 是 我 的 責 任 \n',
#  '可 能 有 生 命 危 險 \n',
#  '哪 有 人 傍 晚 辦 交 屋 的 \n',
#  '所 以 才 叫 妳 放 心 \n',
#  '為 什 麼 媽 媽 跟 妳 說 這 些 \n',
#  '妳 眼 皮 較 薄 \n',
#  '乖 \n',
#  '我 進 去 煮 給 妳 吃 \n',
#  '我 沒 有 \n',
#  '然 後 你 會 把 劉 家 \n',
#  '今 天 要 不 是 我 去 城 隍 廟 \n',
#  '不 在 乎 天 長 地 久 \n',
#  '不 要 這 樣 \n',
#  '讓 他 知 道 \n',
#  '你 敢 \n',
#  '好 啊 你 打 \n',
#  '房 卡 給 妳 \n',
#  '你 兒 子 的 狀 況 確 實 很 危 急 \n',
#  '請 妳 節 哀 順 變 \n',
#  '別 生 我 的 氣 了 好 嗎 \n',
#  '我 也 很 了 解 這 種 心 情 \n',
#  '袋 子 怎 麼 可 能 在 我 車 上 呢 \n',
#  '你 忙 \n',
#  '沒 問 題 \n',
#  '你 一 句 沒 有 感 情 \n',
#  '剛 才 是 意 外 \n',
#  '我 相 信 妳 媽 媽 \n',
#  '希 望 妳 能 夠 自 愛 \n',
#  '所 以 要 早 點 告 訴 我 們 \n',
#  '也 許 我 可 以 把 孩 子 送 回 去 \n',
#  '不 好 意 思 我 今 天 不 能 喝 \n',
#  '妳 快 拿 去 \n',
#  '妳 想 想 \n',
#  '妳 何 時 發 現 的 \n',
#  '妳 想 想 \n',
#  '誰 知 道 張 美 純 \n',
#  '就 浮 現 那 個 人 的 臉 \n',
#  '我 也 同 意 \n',
#  '還 害 文 進 賠 錢 \n',
#  '那 邊 坐 \n',
#  '好 了 不 要 說 話 安 靜 \n',
#  '現 在 要 等 病 人 清 醒 \n',
#  '再 怎 麼 忙 \n',
#  '阿 嬤 這 裡 的 媽 祖 娘 娘 很 靈 驗 \n',
#  '能 夠 爭 取 雙 方 家 長 的 同 意 \n',
#  '妳 沒 事 吧 \n',
#  '問 題 是 俊 傑 開 酒 店 \n',
#  '還 炒 了 一 些 你 喜 歡 吃 的 菜 \n',
#  '你 怎 麼 買 到 的 \n',
#  '妳 剛 才 幫 叔 叔 相 親 嗎 \n',
#  '如 果 我 要 收 你 的 錢 \n',
#  '是 妳 啊 \n',
#  '鬼 扯 什 麼 \n',
#  '哪 間 醫 院 \n',
#  '這 \n',
#  '對 耶 \n',
#  '聽 不 進 去 \n',
#  '像 你 這 種 社 會 敗 類 \n',
#  '放 在 這 裡 這 裡 \n',
#  '活 到 這 把 歲 數 \n',
#  '來 \n',
#  '你 怎 麼 會 不 知 道 \n',
#  '不 認 識 就 不 認 識 \n',
#  '那 個 臭 小 子 的 陷 害 設 計 \n',
#  '來 談 公 事 \n',
#  '你 們 這 樣 \n',
#  '綁 頭 髮 \n',
#  '剛 才 為 什 麼 不 說 \n',
#  '你 是 不 敢 吧 \n',
#  '阿 旺 伯 阿 土 伯 \n',
#  '不 行 \n',
#  '你 們 有 所 不 知 \n',
#  '少 囉 嗦 快 去 \n',
#  '這 是 我 家 \n',
#  '她 一 定 告 訴 我 媽 \n',
#  '對 了 \n',
#  '不 在 \n',
#  '小 心 開 車 \n',
#  '這 些 菜 我 不 要 了 \n',
#  '一 棵 開 花 的 樹 啊 \n',
#  '如 果 換 成 我 \n',
#  '高 先 生 \n',
#  '你 真 是 老 古 板 耶 \n',
#  '我 先 走 了 \n',
#  '出 來 旅 遊 有 什 麼 關 係 \n',
#  '我 們 董 事 長 為 人 正 直 \n',
#  '高 文 揚 \n',
#  '好 了 \n',
#  '以 及 兩 個 孩 子 的 阿 姨 \n',
#  '說 不 定 這 件 事 \n',
#  '你 開 口 閉 口 都 是 方 慶 堂 \n',
#  '現 在 才 剛 說 到 妳 \n',
#  '我 告 訴 你 \n',
#  '我 會 照 顧 你 \n',
#  '好 吧 \n',
#  '好 \n',
#  '小 姐 還 沒 到 站 耶 \n',
#  '昭 華 弄 丟 的 護 照 跟 機 票 \n',
#  '對 啊 \n',
#  '你 說 一 動 也 不 動 的 意 思 是 \n',
#  '阿 嬤 \n',
#  '好 啦 \n',
#  '你 們 兩 個 當 警 察 多 久 了 \n',
#  '皮 肉 傷 而 已 \n',
#  '凡 事 講 求 證 據 \n',
#  '偶 然 間 這 一 刻 \n',
#  '沒 事 \n',
#  '你 硬 勉 強 他 也 沒 用 \n',
#  '文 隆 \n',
#  '沒 有 痛 \n',
#  '王 先 生 \n',
#  '好 美 \n',
#  '來 啦 \n',
#  '他 的 個 性 我 最 了 解 了 \n',
#  '都 想 照 顧 才 會 這 樣 \n',
#  '這 麼 厲 害 \n',
#  '記 得 幫 我 們 公 司 宣 傳 哦 \n',
#  '我 等 著 瞧 \n',
#  '小 辣 椒 \n',
#  '妳 再 親 自 出 馬 不 就 好 了 嗎 \n',
#  '結 果 千 金 大 小 姐 怎 麼 樣 \n',
#  '我 已 經 安 排 好 了 \n',
#  '文 琪 妳 也 很 奇 怪 \n',
#  '對 了 \n',
#  '正 因 他 這 麼 無 情 無 義 \n',
#  '不 用 \n',
#  '你 說 得 太 誇 張 了 \n',
#  '沒 有 \n',
#  '你 仗 著 自 己 是 律 師 \n',
#  '吃 藥 啦 \n',
#  '就 是 這 支 籤 了 \n',
#  ...]
